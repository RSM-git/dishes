# %%
from pathlib import Path
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
from dataclasses import dataclass

from src.data import load_data, parse_json_columns

# %%
### 
data_path = Path("data/raw/recipes.csv")

df = load_data(path=data_path)

df = parse_json_columns(df=df)

# df.head()

print(len(df))

df = df.unique()

print(len(df))

for ingredients in df["ingredients"]:
    for ingredient in ingredients:
        if "tomato" in ingredient:
            print(ingredient)
# Out:
# 62126
# 62126
# 1 ½ teaspoons tomato paste
# 1 (28 ounce) can diced tomatoes
# 1 large tomato, chopped
# 1 ripe tomato, chopped
# 2 (10.75 ounce) cans low sodium tomato soup
# 8 ounces cherry tomatoes, halved
# 1 (14.5 ounce) can stewed tomatoes
# 1 (10 ounce) can diced tomatoes and green chiles (such as RO*TEL®)
# 1 (6 ounce) can tomato paste
# 2 tablespoons tomato paste
# 1 slice tomato
# 3 roma (plum) tomatoes, diced
# 1 (14.5 ounce) can diced tomatoes
# 1 tomato
# 2 Roma tomatoes
# 1 (14.5 ounce) can diced tomatoes, drained
# ¼ cup cherry tomatoes for garnish
# 1 (14.5 ounce can) tomatoes
# 1 pint cherry tomatoes
# 6 Roma (plum) tomatoes, chopped
# 1 (16 ounce) can whole peeled tomatoes, chopped
# 1 small tomato, chopped
# 3 tablespoons tomato paste
# 4 roma (plum) tomatoes, diced
# 1 (10 ounce) can diced tomatoes with green chile peppers, with liquid
# 2 ripe fresh tomatoes, chopped
# 3 (6 ounce) cans tomato paste
# 1 (15 ounce) can tomato sauce
# 1 ½ tablespoons tomato paste
# 1 small tomato, diced
# 1 roma tomato, sliced
# 1 (14.5 ounce) cans fire roasted diced tomatoes
# 3 tomatoes, cut into small pieces
# 3 large tomatoes, seeded and chopped
# 1 (10-ounce can tomato soup
# 3 cups chopped fresh tomatoes
# ¼ cup tomato sauce
# 6 Roma (plum) tomatoes, chopped
# 4 slices tomato
# 48 ounces chunky tomato sauce
# 1 large tomato, diced
# 2 roma (plum) tomatoes, diced
# 1 (6 ounce) can tomato paste
# 1 (28 ounce) can crushed San Marzano tomatoes
# 12 ½ cups chopped green tomatoes
# 2 tomatoes
# 1 tomato, diced
# 2 tablespoons tomato paste
# 1/3 cup sun-dried tomatoes in oil
# 1 (14.5 ounce) can diced tomatoes
# 1 small tomato, diced
# 2 tomatoes, chopped
# 3 cups freshly chopped tomatoes
# 4 cherry tomatoes, sliced
# 1 large tomato, diced
# 1 (28 ounce) can crushed tomatoes, with liquid
# 2 cups spicy tomato sauce
# 1 Roma tomato, seeded and diced
# 3 tablespoons tomato paste
# 1 pound grape tomatoes
# grape tomatoes
# 2 pounds green tomatoes, sliced
# 1 (14.5 ounce) can diced tomatoes with juice
# 1 (14.5 ounce) can Mexican-style stewed tomatoes with chiles, undrained
# 1 (14.5 ounce) can diced tomatoes, undrained
# 6 grape tomatoes, halved
# ⅓ cup oil-packed sun-dried tomatoes, drained and cut into strips
# 1 pint grape tomatoes, halved
# 1 (14.5 ounce) can stewed tomatoes
# 1 (14.5 ounce) can crushed tomatoes
# 1 (28 ounce) can diced tomatoes
# 1 (15 ounce) can tomato purée
# 1 (8 ounce) can chopped tomatoes
# 2 (8 ounce) cans tomato sauce
# 5 large tomatoes, chopped
# 1 ½ cups crushed and strained tomatoes (such as Aurora)
# 1 tablespoon tomato paste (Optional)
# 1 tablespoon tomato sauce
# 1 (16 ounce) can tomato sauce (such as Pomì)
# 1 tomato, sliced
# 1 tomato, chopped
# 1 ½ tablespoons tomato paste
# 1 ½ pounds tomatoes, halved
# 1 (14.5 ounce) can fire-roasted diced tomatoes
# 1 tablespoon tomato paste
# 1 (14.5 ounce) can diced tomatoes with juice
# 1 (6 ounce) can tomato paste
# 2 tomatoes
# 1 (8 ounce) can tomato sauce
# 1 medium tomato, diced
# 3 tomatoes, sliced
# 1 (14.5 ounce) can diced tomatoes with green peppers and onions
# 1 tablespoon tomato paste
# 1 tomato, chopped
# 4 ripe Roma tomatoes, diced
# 4 (12 ounce) cans tomato-vegetable juice cocktail (such as V8)
# 1 (16 ounce) can diced tomatoes
# 1 cup chopped fresh tomato
# 2 (28 ounce) cans tomatoes, undrained
# 1 (28 ounce) can tomato sauce (such as Dei Fratelli®)
# 1 (16 ounce) can diced tomatoes
# 1 (14.5 ounce) can peeled and diced tomatoes with juice
# 2 (6 ounce) cans tomato paste
# 2 tomatoes, diced
# 1 cup cherry tomato halves
# 1 (14.5 ounce) can diced tomatoes
# 1 (8 ounce) can tomato sauce
# 1 Roma tomato, seeded and finely chopped
# 1 tablespoon tomato paste
# 2 teaspoons tomato paste
# 1 small tomato, chopped
# 1 (28 ounce) can diced fire-roasted tomatoes
# 1 (16 ounce) can tomato sauce
# 1 (14.5 ounce) can stewed tomatoes, chopped
# 1 (6 ounce) can tomato paste
# 3/4 cup sun-dried tomatoes
# 1 tablespoon oil from sun-dried tomato jar
# 3 tablespoons tomato paste
# 4 roma (plum) tomatoes, chopped
# 2 medium Roma (plum) tomatoes, diced
# 1 (14.5 ounce) can stewed tomatoes
# 1 (6 ounce) can tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 1 (12 ounce) can tomato paste
# 1 1/2 cups grape tomatoes, quartered
# 1 cup diced fresh tomatoes
# 1 (10.75 ounce) can condensed tomato soup
# 1 (8 ounce) can tomato sauce
# 3 large ripe tomatoes, chopped
# 6 large tomatoes, diced
# 3 cups chopped fresh tomatoes
# 1 (28 ounce) can Italian plum tomatoes
# 6 ounces tomato sauce
# 1 (28 ounce) can whole Italian plum tomatoes (preferably San Marzano)
# 2 vine-ripened tomatoes, cut into 1/4-inch slices
# 1 oma tomato, sliced
# 1 (28 ounce) can whole peeled tomatoes with liquid, chopped
# 1 (14.5 ounce) can diced tomatoes, drained
# 1 tablespoon tomato paste
# 1 10 ounce) can diced tomatoes with Hatch green chiles
# 3 large tomatoes, seeded and chopped
# 1 (28 ounce) can diced tomatoes
# 1 (8 ounce) can tomato sauce
# 1 (28 ounce) can crushed tomatoes
# 1 (14 ounce) can diced tomatoes
# 3 large tomatoes, sliced
# 1 tablespoon tomato paste
# 1 (6.5 ounce) can tomato sauce
# ¼ cup tomato sauce
# ½ (14.5 ounce) can chopped tomatoes, drained
# 2 (14.5 ounce) cans no-salt-added diced tomatoes
# 2 (10 ounce) cans tomato sauce
# 1 (14.5 ounce) can Italian-style stewed tomatoes
# 1 large tomato
# 2 ½ pounds fresh ripe tomatoes - stemmed, peeled, and seeded
# 1 cup halved grape tomatoes
# 2 tablespoons tomato paste
# 1 (28 ounce) can diced tomatoes with juice
# ½ cup diced tomatoes
# 2 tablespoons tomato paste
# 2 roma (plum) tomatoes, seeded and chopped
# 1 (8 ounce) can tomato sauce
# 3 (15 ounce) cans diced tomatoes with green chile peppers
# 6 oil-packed sun-dried tomatoes, drained
# 1 (28 ounce) can crushed tomatoes
# 1 tablespoon tomato paste
# 3 (10.5 ounce) cans condensed tomato soup
# 2 (12 fluid ounce) cans tomato juice, or more to taste
# 1 (14.5 ounce) can stewed tomatoes
# 1 (8 ounce) can tomato sauce
# 2 roma (plum) tomatoes, diced
# 1 (14.5 ounce) can stewed tomatoes
# 1 (6 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 1 (28 ounce) can crushed tomatoes
# 8 Roma (plum) tomatoes, seeded and chopped
# 1 (28 ounce) can crushed tomatoes
# 5 medium green tomatoes, chopped
# 2 (15 ounce) cans tomato sauce
# 3 tomatoes, sliced
# 1 cup chopped fresh tomato
# 3 tablespoons tomato paste
# 5 ripe tomatoes, finely diced
# 3 small tomatoes, diced
# 2 tablespoons oil-packed sun-dried tomatoes
# 2 medium tomatoes, chopped
# 1 (8 ounce) can tomato sauce
# 1 tomato, chopped, or more as needed
# 1 (14.5 ounce) can fire-roasted tomatoes
# ½ pint cherry tomatoes, diced
# 1 tomato, cut into large chunks
# ½ (14.5 ounce) can diced tomatoes, drained
# 1 cup cherry tomatoes
# 1 (14.5 ounce) can chopped tomatoes in puree
# 1 (14.5 ounce) can stewed tomatoes
# 1 (6 ounce) can tomato sauce
# 1 (29 ounce) can diced tomatoes
# 1 (15 ounce) can tomato sauce
# 1 roma tomato, sliced
# 1 can fire-roasted diced tomatoes, undrained
# 1 (10 ounce) can diced tomatoes with green chile peppers (such as RO*TEL®)
# 1 (14.5 ounce) tomatoes with green chilies
# 2 tablespoons tomato paste
# 2 Roma tomatoes
# 1 (14.5 ounce) can chopped tomatoes in puree
# 1 (10 ounce) can diced tomatoes and green chiles (such as RO*TEL)
# 1 vine-ripened tomato, cored and cut into 1/2-inch slices
# 1 pint grape tomatoes
# 1 large tomato, diced
# 1 (14.5 ounce) can diced tomatoes
# 1 (11.5 ounce) can tomato-vegetable juice cocktail
# 3 tablespoons tomato paste
# 2 (10 ounce) baskets cherry tomatoes
# 6 Roma tomatoes, sliced into rounds
# 1 tablespoon tomato-based chili sauce
# 2 medium tomatoes, chopped
# 1 (18 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 2 (28 ounce) cans whole peeled tomatoes
# 1 (29 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# fresh tomato
# 3 tomatoes, chopped
# 2 Roma tomatoes
# 1 (8 ounce) can tomato sauce
# 1/2 cup cherry tomatoes, halved
# 4 teaspoons tomato paste
# 2 ½ cups Roma (plum) tomatoes, seeded and chopped
# 4 (14.5 ounce) cans stewed tomatoes
# ⅓ cup tomato paste
# 1 (28 ounce) can whole peeled tomatoes, with liquid
# 1 (26 ounce) can condensed tomato soup
# 1 Roma tomato, chopped
# 4 tomatoes, diced
# 1 tomato Roma tomato
# 2 pounds tomatoes, sliced
# 6 roma (plum) tomatoes, diced
# ½ cup condensed tomato soup
# 2 medium ripe plum tomatoes, diced
# 1 tablespoon tomato paste
# ½ cup seeded and diced tomato
# 1 (14.5 ounce) can diced tomatoes
# ½ cup diced tomatoes, or to taste (Optional)
# 1 plum tomato, chopped
# 1 large tomato, diced
# 1 ½ cups halved cherry tomatoes
# 1 roma tomato, quartered
# 1 tablespoon tomato paste
# 5 tomatoes, diced
# 2 large fresh tomatoes, diced
# 1 (15 ounce) can tomato sauce
# 1 (14.5 ounce) can stewed tomatoes
# 12 cherry tomatoes
# ½ cup grape tomatoes
# 2 (10 ounce) cans diced tomatoes with green chiles, undrained
# 1 (8 ounce) can tomato sauce
# ½ cup oil-packed sun-dried tomatoes, drained
# 1 ½ pounds tomatoes, chopped
# 3 cups tomato sauce, or to taste
# 1 (14.5 ounce) can fire-roasted diced tomatoes
# 1 (8 ounce) can tomato sauce
# 1 tablespoon tomato paste
# 5 plum tomatoes, thinly sliced
# 2 tomatoes, diced
# 1 (10 ounce) can diced tomatoes with green chile peppers, drained
# 1 (14.5 ounce) can Italian-style diced tomatoes, undrained
# 1 tablespoon tomato paste
# 1 medium tomato, finely chopped
# 2 cups tomato juice
# 2 (28 ounce) cans diced tomatoes with juice
# 1 (6 ounce) can tomato paste
# 3 large roma (plum) tomatoes, diced
# 1 (8 ounce) container grape tomatoes, halved
# 4 (8 ounce) cans tomato sauce
# 4 plum tomatoes, chopped
# ½ cup diced tomatoes
# 1 (10 ounce) can diced tomatoes and green chiles
# 1 (14.5 ounce) can diced tomatoes
# 2 (14.5 ounce) cans no-salt-added tomatoes, diced or crushed
# 1 (28 ounce) can crushed tomatoes
# ½ cup chopped sun-dried tomatoes
# 2 large tomatoes, finely chopped
# ½ cup sliced sun-dried tomatoes, drained (packed in oil)
# 12 cherry tomatoes
# 1 ripe tomato, chopped
# 2 fresh tomatoes, diced
# 2 medium tomatoes, chopped
# ¼ cup tomato sauce
# 1 (8 ounce) can tomato sauce
# 2 cups tomato sauce
# 1 (28 ounce) can diced tomatoes, with liquid
# ½ cup cherry tomatoes, halved
# 1 cup cherry tomatoes, halved
# ¼ cup tomato sauce
# 2 tomatoes, cut into wedges
# 1 (28 ounce) can crushed tomatoes
# 1 (16 ounce) can tomato sauce
# 1 cup tomato paste
# ½ cup cherry tomato halves
# 1 cup cherry tomatoes, halved
# 1 (15 ounce) can tomato sauce, divided
# 2 tablespoons finely chopped dried tomatoes
# 1 tablespoon tomato paste
# 8 tomatoes
# 1 cup canned diced tomatoes
# 2 tablespoons canned tomato paste
# 1 cup chopped tomatoes
# 1/4 cup cherry tomatoes
# 1 (28 ounce) can crushed tomatoes
# 1 (10 ounce) can diced tomatoes with green chile peppers (such as RO*TEL®)
# 2 medium Roma (plum) tomatoes, diced
# 1 (15 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 1 (28 ounce) can diced tomatoes
# 1 (14.5 ounce) can diced tomatoes with roasted garlic
# 3 large tomatoes, diced
# 1 (10 ounce) can tomato sauce
# 1 cup stewed tomatoes
# 1 pound canned tomatoes
# 1 quart tomato sauce
# 5 cherry tomatoes, halved
# 1 (29 ounce) can crushed tomatoes
# 2 cups halved grape tomatoes, well drained
# 2 tomatoes, diced
# 1 pound roma (plum) tomatoes, chopped
# 2 (12 ounce) cans diced tomatoes with juice
# 2 cups cherry tomatoes
# 2 (14.5 ounce) cans diced tomatoes
# 1 (6 ounce) can tomato paste
# 2 (10.75 ounce) cans condensed tomato soup
# 2 tablespoons tomato paste
# ¼ cup diced tomatoes, or to taste (Optional)
# 1 large tomato, chopped
# 2 roma (plum) tomatoes, diced
# 2 tablespoons tomato paste
# 3 plum tomatoes - peeled, seeded, and chopped
# 2 cups chopped tomatoes
# 1 (28 ounce) can crushed tomatoes
# 1 (15 ounce) can tomato sauce
# 1 (14.5 ounce) can stewed tomatoes
# 1 (10 ounce) can diced tomatoes and green chiles (such as RO*TEL®)
# 1 (6 ounce) can tomato paste
# 4 Roma tomatoes,
# 1 tablespoon tomato paste
# 1 (28 ounce) can crushed tomatoes
# 1 (14 ounce) can diced tomatoes
# 2 tablespoons tomato paste
# 2 tomatoes, chopped
# 1/4 cup marinara or other prepared tomato sauce
# 2 Roma tomatoes, diced
# ¼ cup chopped sun-dried tomatoes
# 1 (10.75 ounce) can condensed tomato soup
# 1 tomato, diced
# 2 tablespoons tomato paste
# 3 roma (plum) tomatoes, seeded and chopped
# 2 large roma (plum) tomatoes, chopped
# 1 (28 ounce) can whole peeled tomatoes with juice
# 3 large tomatoes, diced
# 1 tomato
# 1 (6 ounce) can tomato paste
# 1 small tomato, chopped
# 3 tomatoes, chopped
# 1 (14.5 ounce) can diced tomatoes, undrained
# 1 (8 ounce) can tomato sauce
# 1 (8 ounce) can tomato sauce
# 20 grape or cherry tomatoes, halved
# 1 tomato, chopped
# 2 plum tomatoes, chopped
# 1 (14.5 ounce) can no-salt-added diced tomatoes
# 1 (6 ounce) can tomato paste
# 1 cup cherry tomatoes
# 1 (14.5 ounce) can petite diced tomatoes, undrained
# 1 (14.5 ounce) can Italian-style diced tomatoes, drained
# 2 medium tomatoes, sliced
# 1 (28 ounce) can crushed tomatoes
# 2 (16 ounce) cans whole peeled tomatoes, drained
# 3 ounces tomato paste
# ½ ripe tomato
# 1 (29 ounce) can tomato sauce
# 1 (14.5 ounce) can peeled and diced tomatoes with juice
# 2 (6 ounce) cans tomato paste
# 1 cup chopped fresh tomatoes
# 1 large tomato, diced
# 1 tomato, diced
# 1 (14 ounce) can peeled and diced tomatoes with juice
# 2 small tomatoes, diced
# 1 small tomato, thinly sliced
# 1 (10.75 ounce) can condensed tomato soup, divided
# 1 (6 ounce) can tomato paste
# 1 tablespoon tomato paste
# 1 cup cherry tomatoes
# 1 (10 ounce) can diced tomatoes with green chile peppers (such as RO*TEL®)
# 1 (12 ounce) bottle tomato-based chili sauce
# 4 large tomatoes, peeled and sliced
# 1 (8 ounce) can tomato sauce
# 2 pounds green tomatoes, sliced
# 5 cups chopped green tomatoes
# 2 (10.75 ounce) cans tomato soup
# 2 cups chopped tomatoes
# 1 (10.75 ounce) can tomato soup
# 1 (8 ounce) can tomato sauce
# 10 ripe tomatoes
# 1 (10 ounce) can diced tomatoes with green chiles
# 1 (15 ounce) can diced tomatoes with basil, garlic, and oregano
# ½ (6 ounce) can tomato paste
# 1 cup drained jarred julienne-cut sun-dried tomatoes
# 4 tablespoons oil from sun-dried tomato jar
# 2 tablespoons tomato paste
# 2 roma tomatoes - peeled, seeded and chopped
# 6 slices tomato
# 16 ounces cherry tomatoes,
# 1 (28 ounce) can diced tomatoes, with juice
# 1/4 cup cherry tomatoes
# 1 (10 ounce) can diced tomatoes with green chiles
# 3 (29 ounce) cans tomato sauce
# 1 (6 ounce) can tomato paste
# 1 tablespoon tomato paste
# 2 cups diced Roma tomatoes
# 2 cups cherry tomatoes, halved
# 1 Roma (plum) tomato, diced
# ½ cup cherry tomato halves
# 2 tablespoons tomato paste
# 1 (16 ounce) can tomato sauce
# 1 cup tomato paste
# 1 tomato, diced
# 1 oil-packed sun-dried tomato, chopped
# 1 tomato, diced
# 2 cups cherry tomatoes, halved
# ⅓ cup oil-packed sun-dried tomatoes, drained and cut into strips
# 1 (15 ounce) can tomato sauce
# 1/2 cup sundried tomatoes
# 2 (10.75 ounce) cans low sodium tomato soup
# 1 ripe tomato, seeded and chopped
# 1 ¾ cups tomato puree (passata)
# 1 (16 ounce) can diced tomatoes with green chile peppers
# 1 (4 ounce) can tomato sauce
# 1 ½ (8 ounce) cans tomato sauce
# 2 cups minced tomato
# 2 (10.75 ounce) cans tomato puree
# 1 (28 ounce) can crushed tomatoes
# 2 (16 ounce) cans whole peeled tomatoes, drained
# 3 ounces tomato paste
# ¾ cup tomato sauce
# 2 ¾ cups canned tomato sauce
# 5 medium Roma tomatoes, diced
# 1 (15 ounce) can tomato sauce
# 2 (10.75 ounce) cans condensed tomato soup
# 1 (29 ounce) can diced tomatoes
# 3 tomatoes, seeded and chopped
# 5 cups canned diced tomatoes with their juice
# 1 cup cherry tomatoes, halved
# 12 cherry tomatoes, halved
# 1 (14.5 ounce) can chopped tomatoes
# ¼ cup tomato paste
# 2 fresh tomatoes, chopped
# 3 tomatoes, chopped
# 1 pint cherry tomatoes
# 1 tomato, diced
# 1 medium tomato, seeded and chopped
# 1 (14.5 ounce) can stewed tomatoes
# 1 (6 ounce) can tomato sauce
# 2 fresh tomatoes, chopped
# 1 (14 ounce) can diced tomatoes
# 1 pint cherry tomatoes
# 1 pound tomato basil chicken sausage
# 1 (14.5 ounce) can diced tomatoes
# 1 (6 ounce) can tomato paste
# 2 cups seasoned tomato sauce, warmed
# 1 (14.5 ounce) can diced tomatoes
# 1 (28 ounce) can fire-roasted diced tomatoes
# 2 medium tomatoes, peeled and chopped
# 1 (8 ounce) can tomato sauce
# 1 large tomato, chopped
# 1 (10-ounce can tomato soup
# 2 large tomatoes, chopped
# 2 medium Roma (plum) tomatoes, diced
# 1 (28 ounce) can tomato sauce
# 3 (28 ounce) cans crushed tomatoes
# 1 (10 ounce) can diced tomatoes and green chiles (such as RO*TEL®)
# 1 ½ cups chopped tomatoes
# 1 (8 ounce) can tomato sauce
# 2 large tomatoes, chopped
# 1 cup tomato salsa
# 4 large green tomatoes
# 3 tomatoes, diced
# 2 Roma tomatoes
# 2 tablespoons tomato paste
# 1 (28 ounce) can diced tomatoes
# 1 (14.5 ounce) can diced tomatoes with roasted garlic
# 1 (10.75 ounce) can condensed tomato soup
# 2 tomatoes, chopped
# 1 (14.5 ounce) can chopped plum tomatoes
# ¾ cup Italian tomato sauce
# 2 tomatoes, chopped
# 1 Roma tomato
# 1 (8 ounce) can tomato sauce
# 1 (10 ounce) can canned diced tomatoes and green chiles, drained
# 1 (28 ounce) can whole tomatoes in juice
# 1 ½ pounds plum tomatoes, seeded and cut into small dice
# ½ cup tomato-vegetable juice cocktail
# 1 (28 ounce) can crushed tomatoes with tomato purée
# 2 large tomatoes, chopped
# 1 tablespoon tomato paste
# 1 (14.5-ounce) can diced tomatoes, undrained
# 1 (8-ounce) can tomato sauce
# 1 (10.75 ounce) can tomato soup
# 3 tomatoes, chopped
# 1 (10 ounce) can diced tomatoes with green chile peppers (such as RO*TEL®), drained
# 2 (15 ounce) cans tomato sauce
# 2 (15 ounce) cans diced tomatoes
# 2 tablespoons tomato sauce
# 3 large tomatoes, cored and chopped
# 4 cups prepared tomato sauce (Optional)
# 1/4 cup tomato paste
# 2 tomatoes, chopped
# 2 (14.5 ounce) cans diced tomatoes with green chile peppers
# ½ cup cherry tomato halves
# 1 (8 ounce) can tomato sauce
# 1 (12 ounce) bottle tomato-based chili sauce
# 2 ½ cups tomato sauce
# 2 tablespoons chopped sun-dried tomatoes
# 1 (24 ounce) jar low-sugar tomato sauce (or your favorite sauce)
# 1 tomato, chopped
# ¾ cup tomato-based chili sauce
# ⅓ cup oil-packed sun-dried tomatoes, drained and cut into strips
# 1/4 cup tomato paste
# 2 (10.75 ounce) cans low sodium tomato soup
# 2 tablespoons tomato paste
# 1 cup cherry or grape tomatoes
# 1 (10 ounce) can diced tomatoes and green chiles
# 4 fluid ounces tomato juice
# 1 (10 ounce) can diced tomatoes with green chile peppers
# 1 (14.5 ounce) cans fire roasted diced tomatoes
# 1 (14.5 ounce) can fire-roasted tomatoes (such as Hunt's®)
# 2 tablespoons tomato puree
# 1 (15 ounce) can diced tomatoes
# 1 (28 ounce) can crushed tomatoes
# 1 (28 ounce) can crushed tomatoes
# 1 (14.5 ounce) can diced tomatoes with green chile peppers (such as RO*TEL®), undrained
# 1 (29 ounce) can diced tomatoes
# 1 (15 ounce) can tomato sauce
# 2 (10.5 ounce) cans diced tomatoes and chilies, such as RO*TEL
# 2 tablespoons tomato paste
# tomatoes,
# 1 pint cherry tomatoes, halved
# 1 (14 ounce) can tomato sauce
# 5 roma (plum) tomatoes, chopped
# 1 (15 ounce) can stewed tomatoes
# 1 (8 ounce) can canned diced tomatoes
# 2 tablespoons canned tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 5 Roma tomatoes
# 2 (14.5 ounce) cans peeled and diced tomatoes
# 2 tablespoons tomato paste
# 2 tomatoes, chopped
# 1 (14.5 ounce) can diced tomatoes
# 1 pound tomatoes, cored and quartered
# 2 (15 ounce) cans diced tomatoes
# 2 (15 ounce) cans tomato sauce
# 1 (28 ounce) can diced tomatoes
# 1 (14.5 ounce) can diced tomatoes with roasted garlic
# 1 (6 ounce) can tomato paste
# 2 medium tomatoes, chopped, or more to taste
# 6 grape tomatoes
# 1 (26 ounce) jar chunky tomato sauce (such as Ragu®)
# 1 (14.5 ounce) can diced tomatoes
# 1 (14.5 ounce) can diced tomatoes, undrained
# 1 (14.5 ounce) can crushed tomatoes
# ¼ cup halved cherry tomatoes
# 1 pint cherry tomatoes
# 1 pound tomato basil chicken sausage
# 1 ½ cups diced roma tomatoes
# 2 tomatoes - blanched, peeled and chopped
# 1 (28 ounce) can crushed tomatoes
# 8 Roma (plum) tomatoes, seeded and chopped
# 2 pints grape tomatoes, halved
# 1 (10.75 ounce) can condensed tomato soup, divided
# 2 (14.5 ounce) cans stewed tomatoes, undrained
# 1 (26 ounce) jar tomato-basil pasta sauce
# 1 ½ cups halved cherry tomatoes
# 1 (28 ounce) can crushed tomatoes
# 2 (6.5 ounce) cans canned tomato sauce
# 2 (6 ounce) cans tomato paste
# 1 tablespoon tomato paste
# 2 tablespoons tomato paste
# 2 (10 ounce) cans diced tomatoes with green chile peppers, drained
# 1 (28 ounce) can Italian-style crushed tomatoes
# ½ cup cherry tomatoes, or to taste
# 2 large tomatoes, chopped
# 10 ounces cherry or grape tomatoes
# ½ cup chopped fresh tomato
# 2 Roma tomatoes, quartered
# 4 fresh tomatoes
# ½ cup chopped, drained oil-packed sun-dried tomatoes
# 1 (10 ounce) can diced tomatoes with green chiles
# 1 (14.5 ounce) can diced tomatoes
# 2 (10.5 ounce) cans condensed tomato soup (such as Campbell's)
# 1 cup tomato juice
# 1 Roma tomato, seeded and chopped into ½-inch pieces
# 1 (28 ounce) can diced fire-roasted tomatoes
# 1 (16 ounce) can tomato sauce
# 3 tomatoes, chopped
# 1 small tomato, seeded and chopped
# 3 cups tomato pasta sauce
# 8 fluid ounces tomato and clam juice cocktail (such as Clamato®)
# 1 (28 ounce) can crushed tomatoes
# 1 ½ tablespoons tomato paste
# 1 ½ cups halved cherry tomatoes
# 1 (28 ounce) can diced tomatoes
# 1 (14.5 ounce) can diced tomatoes with roasted garlic
# 2 ripe plum tomatoes
# ¼ cup chopped sun-dried tomatoes
# 1 (8 ounce) can tomato sauce
# 1/2 cup oil-packed sun-dried tomatoes, chopped
# 1 (8 ounce) can tomato sauce
# 1 (6 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 2 cups cherry tomatoes, halved
# 2 (14.5 ounce) cans diced tomatoes
# 1 (8 ounce) can tomato sauce
# 2 cups tomato sauce
# 2 tablespoons tomato paste
# 6 cherry tomatoes, halved
# 2 (14.5 ounce) cans stewed tomatoes
# 2 cups tomato sauce
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can diced tomatoes
# 4 large ripe tomatoes, chopped
# 1 cup tomato sauce
# 1 (6 ounce) can tomato paste
# 2 tomatoes, diced
# ¼ cup chopped tomatoes
# 3/4 cup sundried tomatoes in oil
# 2 tablespoons tomato paste
# 1 (8 ounce) can tomato sauce
# 1 (28 ounce) can tomatoes
# 2 Roma (plum tomatoes), cored
# ¼ cup canned tomato sauce
# 24 cherry tomatoes, halved
# 1 (14.5 ounce) can diced tomatoes
# 1 cup cherry tomatoes, quartered
# 2 (15 ounce) cans crushed tomatoes
# 2 medium tomatoes, seeded and diced
# 3 tomatoes, chopped
# 2 (14.5 ounce) cans diced tomatoes
# 1 (8 ounce) can tomato sauce
# 1 small tomato, chopped
# 3 medium tomatoes, chopped
# 1 can tomato paste
# 1 can crushed tomatoes with basil
# 2 oma tomatoes, seeded and diced
# 10 cherry tomatoes, halved
# 1 (8 ounce) can tomato sauce
# 1 (10 ounce) can diced tomatoes with green chile peppers
# 1 (16 ounce) can whole peeled tomatoes, chopped
# 2 large tomatoes, coarsely chopped
# 1 (14.5 ounce) can diced tomatoes, drained
# 1 tomato, cut in half
# 1/2 cup sun-dried tomatoes
# 1/4 cup tomato sauce
# 1 (14.5 ounce) can Italian-style diced tomatoes, drained
# 1 (6 ounce) can tomato paste
# 1 (14.25 ounce) can tomato puree
# 1 cup cherry tomatoes, halved
# 1 pint cherry tomatoes
# 4 large tomatoes, chopped
# 2 cups tomato sauce
# 1 (10 ounce) can diced tomatoes with green chile peppers
# 1 (14.5 ounce) can crushed tomatoes
# 2 medium tomatoes, sliced
# 1 pint grape tomatoes, halved
# 2 tablespoons chopped sun-dried tomatoes
# 10 cherry tomatoes, quartered
# 4 thin slices tomato
# 1 (15 ounce) can crushed tomatoes
# 1 (8 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 1 (14.5 ounce) can diced tomatoes, drained
# 2 tablespoons tomato paste
# 1 medium tomato, diced
# 1 (14 ounce) can diced tomatoes with green chile peppers (such as RO*TEL), drained
# ½ cup halved grape tomatoes
# 1 large tomato, peeled and chopped
# 1 (15 ounce) can crushed tomatoes
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can fire-roasted tomatoes,
# 2 (10-ounce) diced tomatoes and green chilies
# 1 (15 ounce) can low-sodium tomato sauce
# 2 cups cherry tomatoes, diced
# ½ cup diced tomatoes
# 1/4 cup marinara or other prepared tomato sauce
# 1 (10 ounce) can diced tomatoes and green chilies, (such as Ro-Tel® Original)
# 1 (10.75 ounce) can condensed tomato soup
# 1 teaspoon tomato paste
# 1 tomato, chopped
# 1 ½ teaspoons tomato paste
# 1 (28 ounce) can diced tomatoes
# 1 cup tomato concassé (see Recipe Tip for the recipe link)
# 1 tomato, seeded and chopped
# 1 (10 ounce) can diced tomatoes and green chilies, (such as Ro-Tel® Original)
# 1 cup cherry tomato halves
# 1 pound grape tomatoes
# 4 tablespoons tomato paste
# ¾ cup spicy tomato-vegetable juice cocktail (such as V8®)
# 1 tablespoon tomato paste
# 1 (10 ounce) can diced tomatoes with green chiles (such as RO*TEL)
# 1 (14.25 ounce) can tomato puree
# ½ cup tomato paste
# 1 (28 ounce) can fire-roasted diced tomatoes with juice
# 1 (6 ounce) can tomato paste
# 2 (14.5 ounce) cans canned diced tomatoes with their juice
# 2 pounds tomatoes
# 1 tablespoon tomato paste
# 1 (15 ounce) can whole peeled tomatoes, mashed
# 1 (16 ounce) can tomato sauce
# 1 (8 ounce) can tomato sauce
# 1/3 cup sun-dried tomatoes
# 1 pint cherry tomatoes
# 2 (15 ounce) cans diced tomatoes
# 1 large tomato, seeded and chopped
# tomato and clam juice cocktail as needed
# 2 tablespoons tomato paste
# 1/3 cup sun-dried tomatoes in oil
# 2 tomatoes, diced
# 2 (14 ounce) cans stewed tomatoes
# 2 ½ cups chopped tomatoes
# 1/2 cup tomatoes
# 1 tablespoon tomato paste
# 1 (14 ounce) can tomato sauce
# 1 (28 ounce) can petite diced tomatoes
# 2 (14.5 ounce) cans diced tomatoes with green chile peppers
# 1 (14 ounce) can tomato sauce
# 2 cups cherry tomatoes, halved
# 1/4 cup drained, chopped sun-dried tomatoes in oil
# 1 cup cherry tomatoes, halved
# 1 ripe tomato, chopped
# 1 cup cherry tomatoes,
# 4 cherry tomatoes
# 3 tomatoes - peeled, seeded and diced
# 2 large tomatoes, diced
# 1 (10 ounce) can diced tomatoes and green chiles, undrained
# 1 medium tomato, chopped, or to taste (Optional)
# 1 ripe tomato, sliced
# 3 (6 ounce) cans tomato paste
# 1 (16 ounce) can crushed tomatoes
# 1 (8 ounce) can diced tomatoes
# 2 tablespoons tomato paste
# 1 (10 ounce) can diced tomatoes with green chilies, drained
# 1 1/2 cups grape tomatoes, quartered
# 1 (14.5 ounce) cans fire roasted diced tomatoes
# 2 cups canned diced tomatoes, with juices
# 1 (10 ounce) package cherry tomatoes
# 1/4 cup tomato paste
# 1 (5-ounce) can tomato sauce
# 1 ripe tomato, chopped
# 2 (8 ounce) cans tomato sauce
# 1 ripe tomato, chopped
# 1 ripe tomato, seeded and chopped
# 1 (14.5 ounce) can diced tomatoes with juice
# 1 (6 ounce) can tomato paste
# 1 cup grape tomatoes
# 1 (28 ounce) can canned crushed tomatoes
# 1 tomato, diced (Optional)
# 1 (28 ounce) can crushed tomatoes
# 1/4 cup tomato paste
# 6 medium tomatoes, chopped
# 1 (28 ounce) can crushed tomatoes
# 3 (28 ounce) cans whole peeled tomatoes, crushed
# 1 (28 ounce) can crushed tomatoes
# 8 Roma (plum) tomatoes, halved
# 1 tomato, chopped
# 1 10 ounce) can diced tomatoes with Hatch green chiles
# 1 (28 ounce) can whole Italian plum tomatoes (preferably San Marzano)
# 1 (6 ounce) can tomato paste
# 1 tablespoon tomato paste
# 2 (10.75 ounce) cans tomato puree
# 2 (28 ounce) cans tomatoes, undrained
# 1 (28 ounce) can tomato sauce (such as Dei Fratelli®)
# 2 tablespoons tomato paste
# 16 ounces cherry tomatoes,
# 4 slices tomato
# 1 (8 ounce) can whole plum tomatoes, coarsely chopped
# 1 (8 ounce) can tomato sauce
# 1 (14.5 ounce) can petite diced tomatoes
# 16 ounces tomato sauce, divided
# 4 medium tomatoes, roughly chopped
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can diced tomatoes
# ½ cup chopped fresh tomato
# 1 ripe tomato, chopped
# 2 (14.5 ounce) cans petite diced tomatoes
# 1 (14.5 ounce) can fire-roasted diced tomatoes
# 1 (8 ounce) can tomato sauce
# 1 (4 ounce) can tomato sauce with garlic and onions
# 1 (14.25 ounce) can tomato puree
# 1 (46 fluid ounce) can tomato juice
# 1 (29 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 1 (6 ounce) can tomato paste
# 1 cup cherry tomatoes,
# 1 large tomato, chopped
# 1 ½ tablespoons tomato paste
# 2 tablespoons tomato paste (optional)
# 1 tablespoon tomato paste
# 1/2 cup sundried tomatoes
# 1 teaspoon tomato paste
# 4 thick slices tomato
# ½ cup chopped cherry tomatoes
# ½ cup tomato sauce
# 1/2 cup tomatoes
# 1 tablespoon tomato paste
# 1 ¼ cups peeled, seeded, diced ripe tomatoes
# 1 (14.5 ounce) can chopped tomatoes
# 3 tablespoons tomato sauce
# ¼ cup smoked sun-dried tomatoes
# 1 large tomato, finely diced
# 2 tomatoes, chopped
# 1 (28-ounce) can whole peeled tomatoes, chopped
# 1 1/2 cups cherry tomatoes,
# 20 cherry tomatoes, halved
# 20 roma (plum) tomatoes
# 20 sun-dried tomatoes packed in oil, drained and chopped
# 1/3 cup sun-dried tomatoes, cut into short, thin strips
# 1 large tomato, chopped
# ½ cup Chopped tomatoes
# 2 pounds tomatoes
# 1 tablespoon tomato paste
# 1 (16 ounce) can crushed Italian tomatoes
# 4 ripe tomatoes, sliced
# 8 grape tomatoes, halved
# 2 (14.5 ounce) cans stewed tomatoes
# 4 small tomatoes
# 1 pound tomatoes, coarsely chopped
# 2 slices plum tomato
# 3 tomatoes, chopped
# 1 (6 ounce) can tomato paste
# 1 (14.25 ounce) can tomato puree
# 1 (10 ounce) can diced tomatoes with green chiles (such as Rotel), drained slightly
# 1 (8 ounce) can tomato sauce
# 2 tablespoons tomato paste
# 4 tomatoes on the vine, cored and chopped
# 1 (28 ounce) can whole peeled tomatoes with juice
# 1 (28 ounce) can diced tomatoes with green chiles (such as Rotel)
# 1 (14.5 ounce) can fire-roasted diced tomatoes with garlic
# 1 (14.5 ounce) can diced tomatoes with green peppers and onions
# 1 (28 ounce) can crushed tomatoes
# 2 (6.5 ounce) cans canned tomato sauce
# 2 (6 ounce) cans tomato paste
# 4 large tomatoes, seeded and diced
# fresh tomato
# 1 (28 ounce) can crushed tomatoes
# 2 (16 ounce) cans whole peeled tomatoes, drained
# 3 ounces tomato paste
# 2 cups tomato sauce
# 1 cup tomato puree
# 5 roma (plum) tomatoes, diced
# 1 (15 ounce) can stewed tomatoes
# 1 (8 ounce) can canned diced tomatoes
# ½ cup chopped tomato
# 2 (10 ounce) cans diced tomatoes and green chiles, undrained
# 1 (8 ounce) can tomato sauce
# 1/2 cup sun-dried tomatoes in oil
# 1 tablespoon oil from sun-dried tomatoes jar
# 1 tablespoon tomato paste
# 2 tomatoes, diced
# 1 (14.5 ounce) can fire-roasted tomatoes,
# 1 cup cherry tomatoes
# 1 (28 ounce) can crushed tomatoes
# 2 cups chopped green tomato
# 8 thin tomato slices
# ¼ cup tomato sauce
# 2 (8-ounce) cans tomato sauce
# 1 (14.5-ounce) can diced tomatoes
# 1 (12 ounce) can tomato paste
# 8 grape tomatoes, chopped
# 1 (14 ounce) can fire-roasted diced tomatoes
# 5 roma (plum) tomatoes, seeded and chopped
# 1 (8 ounce) can tomato sauce
# 1 (10.75 ounce) can tomato soup
# 1 (28 ounce) can diced tomatoes
# 1 (10.5 ounce) can condensed tomato soup
# 1 (16 ounce) can diced tomatoes
# 1 (8 ounce) can tomato sauce
# 8 Roma (plum) tomatoes, cut in half and seeds removed
# 3 tomatoes, diced
# 1 small tomato, finely chopped
# 1 quart stewed tomatoes
# 6 ounces tomato paste (Optional)
# 2 (16 ounce) cans whole peeled tomatoes, chopped, juice reserved
# 1 (12 ounce) can tomato paste
# 1 cup cherry tomatoes,
# 1 (28 ounce) can crushed tomatoes, with liquid
# 1 (15 ounce) can crushed tomatoes
# 1 (6 ounce) can tomato paste
# 2 (14.5 ounce) cans diced tomatoes, undrained
# 3 tablespoons tomato paste
# 1 tablespoon tomato paste
# 2 tablespoons sun dried tomatoes
# 1 cup drained jarred julienne-cut sun-dried tomatoes
# 4 tablespoons oil from sun-dried tomato jar
# 2 tablespoons tomato paste
# 1 large tomato, sliced
# 1 large tomato, finely diced
# 1 (28 ounce) can diced fire-roasted tomatoes
# 1 (16 ounce) can tomato sauce
# 2 (12 ounce) bottles tomato-based chili sauce (such as Heinz)
# ½ pound tomatoes, chopped
# 1 (15 ounce) can tomato sauce
# 1 (14.4 ounce) can diced tomatoes
# 1 (29 ounce) can diced tomatoes
# 2 (6 ounce) cans tomato paste
# 1 ripe tomato, chopped
# 1 cup Heinz tomato ketchup
# 1 (10 ounce) can diced tomatoes with green chiles
# 1 (14.5 ounce) can fire roasted tomatoes
# 1 (4 ounce) can tomato sauce
# 6 sun-dried tomatoes
# 1 medium tomato, sliced
# 2 large tomatoes, diced
# 1 (28 ounce) can diced tomatoes
# 1 (28 ounce) can whole peeled tomatoes
# 2 vine-ripened tomatoes, diced small
# 1 (12 ounce) can tomato paste
# 1 (15 ounce) can tomato sauce
# 2 tomatoes, cubed
# 1 (14.5 ounce) can diced tomatoes, undrained
# 1 (14.5 ounce) can diced tomatoes
# 1 cup halved grape tomatoes
# 1 (15 ounce) can tomato sauce
# 1 (14.5 ounce) can stewed tomatoes
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can diced tomatoes
# 1 (14.5 ounce) can diced tomatoes with juice
# 2 ½ cups assorted cut-up vegetables (broccoli, carrots, tomatoes, bell peppers, cauliflower, onions and mushrooms)
# 1 cup stewed tomatoes
# ¼ cup tomato paste
# 1/4 cup tomato paste
# 1 (14.5 ounce) can diced tomatoes with basil, garlic, and olive oil
# 2 tomatoes, chopped
# 2 cups crushed tomatoes or tomato sauce
# 1 cup red and yellow cherry tomatoes
# 2 (14.5 ounce) cans Mexican-style stewed tomatoes
# 1 cup cherry tomatoes, halved
# 1 (10 ounce) can diced tomatoes with green chilies (such as Rotel® Original)
# 1 large tomato, diced
# 8 ounces cherry tomatoes, halved
# 1 cup halved cherry tomatoes
# 2 tablespoons tomato paste
# 2 (15 ounce) cans tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 1 cup chopped roma (plum) tomatoes
# 8 roma tomatoes, chopped
# 2 tablespoons tomato paste
# 2 tablespoons sun-dried tomatoes in oil
# 1 (10 ounce) can diced tomatoes and green chiles, undrained
# 1 (15 ounce) can tomato sauce
# 2 tablespoons tomato paste
# 2 (10 ounce) cans diced tomatoes and green chiles (such as RO*TEL)
# 2 (16 ounce) cans whole peeled tomatoes
# 1 (16 ounce) can stewed tomatoes, undrained
# 3 cups mashed tomatoes
# 1 (14.5 ounce) can whole peeled tomatoes, chopped
# 8 grape tomatoes, chopped
# 1 (15 ounce) can crushed tomatoes
# 1 (6 ounce) can tomato paste
# 1 oma tomato, sliced
# 1 (8 ounce) can tomato sauce
# 2 (14.5 ounce) cans peeled and diced tomatoes
# 3 tomatoes, halved and sliced
# 1 cup grape tomatoes,
# 2 cups spicy tomato sauce
# 3 cups freshly chopped tomatoes
# 1 slice firm-ripe tomato
# 6 roma (plum) tomatoes, diced
# 1 tomato, chopped
# 1 (28 ounce) can diced tomatoes
# 1 (6 ounce) can tomato paste
# ½ cup cherry tomato halves
# 3 Roma tomatoes, seeded and finely chopped
# 2 tablespoons tomato paste
# 1 large ripe tomato, chopped
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can crushed tomatoes, or coarsely chopped tomatoes packed in puree
# 1 (28 ounce) can crushed tomatoes
# ½ cup chopped tomatoes
# 1 (6 ounce) can tomato sauce
# 1 large ripe tomato, chopped
# 15 ounces prepared tomato sauce
# ¼ teaspoon tomato paste
# 4 tomatoes, cut into 8 wedges
# 1 (14.5 ounce) can stewed tomatoes
# 3 cups crushed or puréed tomatoes
# 1 large ripe tomato
# 1 large ripe tomato, diced
# 1 (6 ounce) jar sun-dried tomatoes packed in oil, drained and chopped
# 4 large fresh tomatoes
# 1 large tomato, diced
# 1/4 cup tomato paste
# 3 cups tomatoes, chopped
# 1 (15 ounce) can crushed tomatoes
# 1 (8 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 1 (28 ounce) can diced tomatoes
# 2 tablespoons tomato paste
# 12 ½ cups chopped green tomatoes
# 1 (10 ounce) can diced tomatoes with green chile peppers
# 1 cup tomato sauce
# 1 (16 ounce) can diced tomatoes
# 1 Roma tomato, thinly sliced
# 3 (28 ounce) cans whole peeled tomatoes, crushed
# 1 (28 ounce) can stewed tomatoes
# 2 medium tomatoes, peeled and chopped
# ¼ cup chopped sun-dried tomatoes
# ¼ cup chopped sun-dried tomatoes
# 1 (6 ounce) can tomato paste
# 4 (15 ounce) cans diced tomatoes
# 2 tomatoes, chopped
# 1 cup drained jarred julienne-cut sun-dried tomatoes
# 4 tablespoons oil from sun-dried tomato jar
# 2 tablespoons tomato paste
# 2 small tomatoes
# 1 (14.5 ounce) tomatoes with green chilies
# 1 ½ cups canned crushed tomatoes (such as San Marzano)
# 2 (15 ounce) cans crushed tomatoes
# 1 (28 ounce) can diced tomatoes
# 2 (8 ounce) cans tomato sauce
# 2 oma tomatoes, seeded and diced
# 2 (10.75 ounce) cans tomato puree
# 1 (14.5 ounce) can diced tomatoes
# 1 tablespoon tomato paste
# ½ cup seeded and diced tomato
# 2 tablespoons tomato paste
# 1 cup chopped tomatoes
# 1/2 (10-ounce) diced tomatoes with green chiles
# 1 large tomato, thinly sliced
# 1 (8 ounce) can enchilada sauce or tomato sauce
# 2 (15 ounce) cans crushed tomatoes
# 1 (14.5 ounce) can stewed tomatoes, chopped
# 1 (6 ounce) can tomato paste
# 1 (14.5 ounce) can stewed tomatoes
# 1 cup tomato salsa
# 1 large tomato, sliced
# 2 (8 ounce) cans tomato sauce
# 4 large tomatoes, diced
# 1 (14.5 ounce) can fire-roasted diced tomatoes
# 1 (8 ounce) can tomato sauce
# 2 large tomatoes, diced
# 10 sun-dried tomatoes
# 1 (15 ounce) can diced tomatoes with green chile peppers
# 1 ½ tablespoons tomato paste
# 1 (14.5 ounce) can crushed tomatoes
# 1 (28 ounce) can Italian-style plum tomatoes, drained and coarsely chopped
# 1 teaspoon tomato paste
# 1 large tomato, chopped
# 4 cups chopped fresh tomatoes
# 1 (15 ounce) can tomato sauce
# 2 (14.5 ounce) cans stewed tomatoes
# ½ cup chopped fresh tomato
# 4 slices tomato
# 1 (14.5 ounce) can diced tomatoes, drained
# 1 (14.5 ounce) can diced tomatoes
# 1 ½ (8 ounce) cans tomato sauce
# 1 cup tomato puree
# 1 cup sliced cherry tomatoes
# 1 cup cherry tomatoes
# ½ pint cherry tomatoes, diced
# 1 (14.5 ounce) can diced tomatoes
# 4 large tomatoes, chopped
# 2 cups tomato sauce
# 3 cups whole peeled tomatoes with liquid, chopped
# 1 (14.5 ounce) can diced tomatoes with lime juice and cilantro
# 5 tomatoes
# 1 (15 ounce) can tomato sauce
# 2 ripe tomatoes, chopped
# ½ cup halved grape tomatoes
# 1 (14.25 ounce) can tomato puree
# 3 cups cherry tomatoes, halved
# 1 (8 ounce) can tomato sauce
# 1 (28 ounce) can crushed tomatoes
# 1 (8 ounce) can tomato sauce
# 1 pint cherry tomatoes, quartered
# 1 (28 ounce) can crushed San Marzano tomatoes, or other high-quality plum tomatoes
# 2 pounds heirloom tomatoes
# 1 pound Roma tomatoes
# 2 tablespoons tomato paste
# 1/3 cup sun-dried tomatoes in oil
# 1 tomato, cut into wedges
# 1 (14.5 ounce) can diced tomatoes
# 1 (14.5 ounce) can diced tomatoes, drained
# 2 medium tomatoes, cut into chunks
# 4 cups canned crushed tomatoes
# 3 tablespoons tomato paste
# 1 (28 ounce) can whole peeled tomatoes with juice
# 1 (29 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 1 plum tomato, seeded and chopped
# 1 medium tomato, sliced
# 4 grape tomatoes, halved
# 2 (14.5 ounce) cans diced tomatoes, drained
# 1 (8 ounce) can tomato sauce
# 2 tomatoes, cored
# 4 (12 ounce) cans tomato-vegetable juice cocktail (such as V8)
# 2 tomatoes, cut into bite-sized pieces
# 2 pints cherry tomatoes
# 2 tablespoons finely chopped dried tomatoes
# 1 (15 ounce) can Tex Mex-style diced tomatoes
# 2 teaspoons tomato paste
# Diced tomato, as desired
# 1 small tomato, sliced
# 1 pound campari tomatoes, seeded and minced
# 3 roma (plum) tomato, diced
# 1 (28 ounce) can diced tomatoes
# 1 (14.5 ounce) can diced tomatoes with roasted garlic
# 1 (32 ounce) can diced tomatoes
# 1 (14.5 ounce) can diced tomatoes
# 2 (14.5 ounce) cans stewed tomatoes
# 5 cups canned diced tomatoes with their juice
# 1 (28 ounce) can crushed San Marzano tomatoes
# 1 (14.5 ounce) can fire-roasted diced tomatoes
# 1 (12 ounce) can tomato paste
# 8 ounces cherry tomatoes, halved
# 1/4 cup cherry tomatoes
# 2 tomatoes, diced
# 4 Roma tomatoes, halved lengthwise
# 6 slices tomato
# 1 (10 ounce) can diced tomatoes with green chile peppers (such as RO*TEL®)
# ½ (6 ounce) can tomato paste
# 1 (28 ounce) can diced tomatoes
# 1 medium tomato, chopped
# 1 (10.75 ounce) can condensed tomato soup
# 1 (6.5 ounce) can tomato sauce
# 8 roma tomatoes, chopped
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can Italian-style diced tomatoes, drained
# ½ cup chopped, drained oil-packed sun-dried tomatoes
# 2 (8 ounce) cans tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 2 (14.5 ounce) cans diced tomatoes
# 2 pints cherry or grape tomatoes
# 1 (14.5 ounce) can chopped tomatoes
# 10 ripe tomatoes
# 3 cups tomato sauce, or to taste
# 4 tomatoes, chopped
# 1 cup chopped fresh tomato
# 2 (15 ounce) cans tomato sauce
# 1 (15 ounce) can fire-roasted diced tomatoes
# 1 (15 ounce) can crushed tomatoes
# 1 (15-ounce can) tomato sauce
# 2 large fresh tomatoes, diced
# 2 cups chopped tomatoes
# 1 large plum tomato
# 1 cup chopped sun-dried tomatoes
# 2 (10 ounce) cans diced tomatoes with green chile peppers (such as RO*TEL®)
# 1 (14.5 ounce) can diced tomatoes
# 1 (10 ounce) can diced tomatoes with green chilies (such as Rotel® Original)
# 1 large tomato
# 1 small tomato, finely chopped
# 1 (8 ounce) can tomato sauce
# 2 tomatoes, chopped
# 2 (14.5 ounce) cans diced tomatoes with green chile peppers
# 1 (14 ounce) can tomato sauce
# 1 small tomato, chopped
# 1 (15 ounce) can tomato sauce
# 1 (14.4 ounce) can diced tomatoes
# 1 (14 ounce) can diced tomatoes
# 1 (8 ounce) can tomato sauce
# 8 plum tomatoes, diced
# 3 (14.5 ounce) cans chopped tomatoes
# 1 (16 ounce) can tomato sauce
# 4 tomatoes, chopped
# 1 (14.5 ounce) can stewed tomatoes
# 1 (8 ounce) can tomato sauce
# 1 ½ cups tomato sauce
# 5 medium tomatoes, chopped
# 1 (46 fluid ounce) bottle tomato-vegetable juice cocktail
# 2 cups cherry or grape tomatoes
# 30 ounces tomato sauce
# 1 (14 ounce) can cherry tomatoes
# 1 large tomato, seeded and chopped
# 1 (14.5 ounce) can diced tomatoes with juice
# 1 (6 ounce) can tomato paste
# 2 (29 ounce) cans tomato sauce
# 2 (28 ounce) cans peeled and diced tomatoes
# 1 (15 ounce) can stewed tomatoes
# ¼ cup chopped sun-dried tomatoes
# 4 medium tomatoes, diced
# 1 (14.25 ounce) can tomato puree
# 1 tablespoon tomato paste
# 1 (10 ounce) can diced tomatoes and green chiles
# ½ cup tomato juice cocktail (such as Clamato®), chilled
# 10 plum tomatoes, diced
# 1 cup chopped tomatoes
# 1 cup tomato sauce
# 1 cup tomatoes, diced
# 2 (14.5 ounce) cans diced tomatoes
# 1 tablespoon tomato paste
# 1 (14 ounce) can stewed tomatoes
# 2 tablespoons tomato paste
# 5 medium Roma tomatoes, diced
# 2 quarts tomato juice
# 2 (16 ounce) cans whole peeled tomatoes, with liquid
# 2 medium Roma (plum) tomatoes, diced
# 1 (6 ounce) can tomato paste
# 6 large ripe beefsteak tomatoes, chopped
# 1 (15 ounce) can chopped tomatoes
# 20 grape or cherry tomatoes, halved
# 2 (6 ounce) cans tomato paste
# 1 (14.5 ounce) can crushed tomatoes
# 2 cups cherry tomatoes, halved
# ½ (6 ounce) can tomato paste
# 1 (28 ounce) can diced tomatoes
# 4 ounces sun-dried tomatoes
# ⅓ cup crushed tomatoes
# 1 tablespoon tomato paste
# 1 (14.5 ounce) can diced tomatoes with juice
# 1 cup cherry tomatoes,
# 2 ½ cups tomato puree
# 1 (28 ounce) can crushed tomatoes
# 1 (8 ounce) can tomato sauce
# 1 pint grape tomatoes, quartered
# 1 cup chopped tomatoes
# 1 (10 ounce) can diced tomatoes with green chile peppers
# 1 (14.5 ounce) can diced Italian-style tomatoes
# 1 cup cherry tomato halves
# 1 (8 ounce) can tomato sauce
# 4 Roma tomatoes, peeled and seeded
# 1 tablespoon tomato paste
# 1 tomato, chopped
# 1 tablespoon tomato paste
# 4 plum tomatoes, chopped
# 2 tablespoons tomato paste
# 2 (14.5 ounce) cans diced tomatoes with juice
# 1 tablespoon tomato paste
# 1 tomato, chopped
# 3 cups chopped fresh tomatoes
# 2 pints sweet cherry tomatoes
# 1 tomato, chopped
# 10 cherry tomatoes, halved
# 8 cups tomato juice
# 4 (10.75 ounce) cans condensed tomato soup
# 3 green tomatoes
# 1 large red tomato
# 10 plum tomatoes, diced
# 2 (6 ounce) cans tomato paste
# 1 large tomato, sliced
# 2 tablespoons sun-dried tomatoes in oil
# 1 heirloom tomato, sliced
# 1 (14.5 ounce) can fire-roasted tomatoes (such as Hunt's®)
# 1 large tomato, cubed
# 2 (10.75 ounce) cans low sodium tomato soup
# 1 tablespoon tomato paste
# 1 tomato, chopped
# 1 (6 ounce) can tomato paste
# 2 pints cherry or grape tomatoes
# 2 Roma tomatoes, seeded and chopped
# 1 large tomato, chopped
# 2 medium tomatoes, sliced
# 2 cups juicy chopped fresh tomatoes
# 1 (6.5 ounce) can tomato sauce
# 1 ripe tomato, chopped
# 1 (28 ounce) can diced tomatoes
# 1 (14.5 ounce) can stewed tomatoes
# 1 (14.5 ounce) can no-salt-added whole tomatoes, undrained and chopped
# 1/2 cup sun-dried tomatoes
# 1 (28 ounce) can diced tomatoes
# 1 (15 ounce) can tomato purée
# 1 (15 ounce) can tomato sauce
# 1 (28 ounce) can Italian-style peeled tomatoes, crushed by hand
# ¼ cup chopped sun-dried tomatoes
# 2 tablespoons tomato paste
# ¼ cup tomato sauce
# 2 tablespoons tomato paste
# 1 (28 ounce) can canned crushed tomatoes
# 1 (6 ounce) can tomato sauce
# 2 ripe tomatoes, chopped
# ½ tablespoon tomato paste
# 3 roma (plum) tomatoes, chopped
# 1 tablespoon tomato paste
# 1 (14 ounce) can peeled and diced tomatoes with juice
# 4 tomatoes, chopped
# 1 (15 ounce) can Italian-style stewed tomatoes
# 1 (16 ounce) can tomato sauce
# 1 (14.5 ounce) can Italian-style stewed tomatoes (such as Del Monte® Italian Recipe Stewed Tomatoes)
# 1 (14.5 ounce) can peeled and diced tomatoes with juice
# 2 (14.5 ounce cans) diced tomatoes
# 3 (14.5 ounce) cans Mexican-style stewed tomatoes
# 2 (14 ounce) cans stewed tomatoes, with juice
# 1 (15 ounce) can tomato sauce
# ½ cup tomato sauce
# 1 (15 ounce) can tomato sauce
# 3 cups tomato sauce
# 1 (28 ounce) can diced tomatoes with juice
# 1 (28 ounce) can whole peeled tomatoes, drained, juice reserved
# 1 (8 ounce) can tomato sauce
# 1 pound campari tomatoes, seeded and minced
# 4 tomatoes, chopped
# 2 (10.75 ounce) cans low sodium tomato soup
# 2 tablespoons tomato paste
# 1/4 cup tomato paste
# 1 (28 ounce) can diced tomatoes
# 1 (15 ounce) can tomato purée
# 2 Roma tomatoes, seeded and chopped
# 3 (14 ounce) cans stewed tomatoes
# 1 (14 ounce) can tomato sauce
# 1 (10 ounce) can diced tomatoes with green chiles (such as RO*TEL)
# 2 peeled whole canned tomatoes
# 2 (14.5 ounce) cans diced tomatoes
# 2 (10.5 ounce) cans condensed tomato soup
# 1 ripe tomato, chopped
# 1 cup tomato sauce
# 1 (10 ounce) can diced tomatoes and green chiles
# 2 pounds tomatoes, sliced
# 16 ounces cherry tomatoes,
# 3 (8 ounce) cans tomato sauce
# 1 (7.75 ounce) can Mexican style hot tomato sauce (such as El Pato Salsa de Chile Fresco®)
# 1 tomato, diced
# ½ cup halved grape tomatoes
# 1 ripe tomato, chopped
# 1 (14.5 ounce) can no-salt-added diced tomatoes
# 1 (8 ounce) can tomato sauce
# 1 (14.5 ounce) can fire-roasted diced tomatoes
# 4 ripe Roma tomatoes, diced
# 4 tomatoes, chopped
# 6 ounces tomato basil feta cheese, crumbled
# 2 cups fresh tomatoes
# 1 tomato, diced
# 1 (14.25 ounce) can tomato puree
# 1 (8 ounce) can tomato sauce
# 2 (28 ounce) cans tomatoes, undrained
# 1 (10 ounce) can diced tomatoes with green chile peppers (such as RO*TEL), drained
# 1 (10.5 ounce) can condensed tomato soup, divided
# 2 medium Roma (plum) tomatoes, diced
# 1 cup grape tomatoes,
# 2 tomatoes - peeled, seeded, and chopped
# 2 (10.5 ounce) cans condensed tomato soup (such as Campbell's)
# 1 cup tomato juice
# 1 Roma tomato, seeded and chopped into ½-inch pieces
# 2 cups crushed tomatoes or tomato sauce
# 1 (10.5 ounce) can condensed tomato soup
# 1 (8 ounce) can tomato sauce
# 1 (8 ounce) can tomato sauce
# ⅔ (6 ounce) can tomato paste
# 1 large tomato
# 2 tablespoons tomato paste
# 1 (28-ounce) can crushed tomatoes
# 1 (14.5 ounce) can diced tomatoes with juice
# 2 cups halved grape tomatoes, well drained
# 1 medium tomato, seeded and chopped
# 2 teaspoons tomato paste
# 1 cup chopped sun-dried tomatoes
# 1 (14.5 ounce) can peeled and diced tomatoes
# 1 (10 ounce) can diced tomatoes with green chili (such as Rotel®)
# 1 cup drained jarred julienne-cut sun-dried tomatoes
# 4 tablespoons oil from sun-dried tomato jar
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can diced tomatoes
# 1/4 cup tomato paste
# 1 (5-ounce) can tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 1 (18 ounce) can tomato sauce
# 1 (14.5 ounce) can diced tomatoes, undrained
# 6 roma tomatoes, diced
# 1 (10 ounce) can diced tomatoes with green chilies, drained
# 2 cups fresh tomatoes
# 1 (10 ounce) can diced tomatoes and green chiles (such as RO*TEL®)
# 1 (46 fluid ounce) can tomato juice
# 1 (28 ounce) can peeled and diced tomatoes with juice
# 2 (14.5 ounce) cans diced tomatoes
# 1 (8 ounce) can tomato sauce
# 1 cup diced tomatoes (Optional)
# 1 (15 ounce) can diced tomatoes
# 4 large fresh tomatoes, diced
# 6 large tomatoes - peeled, cored, and chopped
# 4 (14.5 ounce) cans stewed tomatoes
# ⅓ cup tomato paste
# 1 (14.5 ounce) can diced tomatoes
# 2 Roma (plum) tomatoes, chopped
# 1 ¾ cups tomato puree (passata)
# 2 (10 ounce) cans diced tomatoes with green chile peppers, partially drained
# 2 tomatoes, diced
# 1 (14.5-ounce) can diced tomatoes, undrained
# 1 (8-ounce) can tomato sauce
# 1 (15 ounce) can tomato sauce
# 1 (14.5 ounce) can whole peeled tomatoes
# 1 (6 ounce) can tomato paste
# 2 cups crushed tomatoes
# 3 (14.5 ounce) cans diced tomatoes
# 1 teaspoon tomato paste
# 1 tomato, chopped
# 1 tablespoon tomato paste
# 8 roma (plum) tomatoes, halved lengthwise and seeded
# 2 roma (plum) tomatoes, diced
# 2 tablespoons tomato paste
# 2 tablespoons tomato paste
# 2 slices tomato
# 1 ripe tomato, seeded and chopped
# 1 tomato, chopped
# 1 (28 ounce) can crushed tomatoes
# 1 (8 ounce) can tomato sauce
# 1 (10.75 ounce) can tomato puree
# 1 (10 ounce) can diced tomatoes and green chiles (such as RO*TEL®)
# 1 (14.5 ounce) can diced tomatoes with onion and celery, drained
# 1 (28 ounce) can crushed tomatoes
# 1 tablespoon tomato paste
# 2 peeled whole canned tomatoes
# 1 tablespoon tomato paste
# 1 cup grape tomatoes
# 2 large tomatoes, chopped
# 2 tablespoons tomato puree
# ½ cup diced tomatoes
# 1 (28 ounce) can diced tomatoes
# 1 (10.75 ounce) can condensed tomato soup
# 3 tomatoes, seeded and chopped
# 1 pint grape tomatoes
# 2 tablespoons oil-packed sun-dried tomatoes
# 1 (14.5 ounce) can diced tomatoes, well drained
# 1 tomato, seeded and chopped
# 1 (24 ounce) jar low-sugar tomato sauce (or your favorite sauce)
# ½ cup diced fresh tomato
# 1 pound grape tomatoes
# 3 cups tomato sauce, or to taste
# 2 tablespoons canned diced tomatoes and green chiles
# 1 (16 ounce) can diced tomatoes with green chile peppers
# 4 ½ cups tomato-basil pasta sauce
# 1 (8 ounce) can tomato sauce
# 1 cup tomatoes, diced
# 1 ¾ cups diced tomatoes
# 1 (6 ounce) can tomato paste
# 1 (15 ounce) can tomato sauce
# 1 cup cherry tomatoes,
# ...
# 2 tomatoes, diced, or more to taste
# 1 (14.5 ounce) can chopped tomatoes in puree
# 3 large Roma tomatoes, halved and seeded
# 2 roma (plum) tomatoes, diced
# 1 large tomato, sliced
# 3 Roma (plum) tomatoes - peeled, seeded, and chopped
# 1 (14.5-ounce) can diced tomatoes and green chiles (such as ROTEL®), drained
# 1 (14.5 ounce) can stewed tomatoes, drained
# 3 (28 ounce) cans whole peeled tomatoes, crushed
# 1 small tomato, seeded and chopped
# 8 ripe plum tomatoes
# 3 pints cherry tomatoes
# 1 (14.5 ounce) can diced tomatoes with oregano and basil
# 1 (6 ounce) can tomato paste
# 1 (14.5 ounce) can diced tomatoes
# 1 pound canned tomatoes
# 2 cups cherry tomatoes, halved
# 1 tablespoon tomato paste
# 1 (8 ounce) can tomato sauce
# 1/4 cup tomato paste
# 3 cups tomato sauce
# 2 (10 ounce) cans tomato sauce
# 2 tablespoons tomato paste
# 10 roma tomatoes
# 2 plum tomatoes, diced
# 1 ½ cups canned diced tomatoes
# 2 ½ cups chopped tomatoes
# 1 (14.5 ounce) can fire-roasted diced tomatoes
# 1 (8 ounce) can tomato sauce
# 2 Roma tomatoes
# 12 cherry tomatoes
# tomato slices, to taste (optional)
# 2 cups crushed tomatoes or tomato sauce
# 2 (28 ounce) cans crushed tomatoes
# ¾ cup tomato puree
# 1 large tomato, chopped
# 2 cups diced Roma tomatoes
# ¼ cup tomato sauce
# 2 (15 ounce) cans tomato sauce
# 2 tomatoes, seeded and chopped
# 1 small tomato, sliced
# 1 tomato, chopped
# 1 (28 ounce) can plum tomatoes, crushed fine
# 4 slices tomato
# 1 tablespoon tomato paste
# 1 (15 ounce) can diced tomatoes
# ½ pint grape tomatoes
# 1 pint cherry tomatoes
# 3 medium tomatoes, chopped
# 1 cup red and yellow cherry tomatoes, halved
# ¼ cup chopped sun-dried tomatoes
# 6 cherry tomatoes, sliced
# 1 large tomato, diced
# ½ cup tomato sauce
# 1 (46 fluid ounce) can tomato juice
# 1 (29 ounce) can tomato sauce
# 1 (14.5 ounce) can stewed, diced tomatoes
# 1 (8 ounce) can tomato sauce
# 3 Roma (plum) tomatoes - peeled, seeded, and chopped
# 1 tomato, diced
# 1 (12 ounce) bottle tomato-based chili sauce
# 1 tomato, cubed
# 1 cup tomato sauce
# 6 cups tomato sauce
# 2 large tomatoes, chopped
# lettuce and tomato slices for serving
# 2 large tomatoes, chopped
# ¼ cup tomato paste
# 1 tablespoon tomato paste
# 2 cups canned tomatoes, drained
# 4 Roma (plum) tomatoes, seeded and chopped
# 1 ripe tomato, chopped
# 2 tablespoons tomato paste
# ½ cup diced Italian tomatoes
# 3 large ripe tomatoes, chopped
# 2 tablespoons tomato paste
# 1 (28-ounce) can crushed tomatoes
# 10 cherry tomatoes, halved
# 2 cups canned crushed tomatoes
# 1 (10 ounce) can diced tomatoes with green chile peppers
# 1 (10 ounce) can diced tomatoes with green chile peppers, lime, and cilantro (such as RO*TEL®)
# 1 (8 ounce) can tomato sauce
# 1 tablespoon tomato paste
# 1 (14.5 ounce) can diced tomatoes
# 3 (6 ounce) cans tomato paste
# 1 (16 ounce) can crushed tomatoes
# 1 (8 ounce) can diced tomatoes
# 1 (10 ounce) can diced tomatoes with green chile peppers
# 1 tablespoon tomato paste
# 1 15-ounce) canned crushed tomatoes
# 1 (28 ounce) can tomato sauce
# 1 (14.5 ounce) can fire roasted diced tomatoes
# 1 (15 ounce) can tomato sauce
# 1 ⅓ (6 ounce) cans tomato paste
# 3 cups cherry tomatoes, halved
# 1 medium tomato, sliced
# 1 (16 ounce) can whole peeled tomatoes, chopped
# 1 (14.5 ounce) can peeled and diced tomatoes with juice
# 1 (16 ounce) can whole peeled tomatoes, chopped
# 4 roma (plum) tomatoes, chopped
# 2 large tomatoes, chopped
# 3 (14.5 ounce) cans whole peeled tomatoes with liquid, chopped
# 1 10 ounce) can tomatoes with green chiles, such as RO*TEL®, drained
# 2 tomatoes, chopped
# 1 (28 ounce) can diced tomatoes
# 1 (8 ounce) can tomato sauce
# 4 grape tomatoes, halved
# 1 cup tomato juice
# 1 (6 ounce) can tomato paste
# 1 (28 ounce) can crushed tomatoes
# 1 (15 ounce) can tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 2 (28 ounce) cans diced tomatoes with juice
# 1 (6 ounce) can tomato paste
# 1 tablespoon tomato paste
# 1 (14 ounce) can tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 1 (12 ounce) can tomato paste
# 8 large ripe tomatoes
# ¼ cup sugar plum tomatoes
# 1 pint cherry tomatoes, halved
# 3 tomatoes, chopped
# fresh tomato
# 1 (15 ounce) can crushed tomatoes
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can stewed tomatoes
# 1 (28 ounce) can diced tomatoes
# 12 large green tomatoes, cut into large chunks
# 1 (14 ounce) can Italian crushed tomatoes with basil
# 1 (10 ounce) can diced tomatoes and green chiles
# 2 (10.75 ounce) cans tomato soup
# 1 large tomato, sliced
# ¾ cup tomato paste
# 2 ½ cups assorted cut-up vegetables (broccoli, carrots, tomatoes, bell peppers, cauliflower, onions and mushrooms)
# 2 large roma (plum) tomatoes, chopped
# 1 (16 ounce) can tomato sauce
# 1 (14.5 ounce) can Italian-style stewed tomatoes (such as Del Monte® Italian Recipe Stewed Tomatoes)
# 1 pint grape tomatoes, halved
# 2 (10.75 ounce) cans tomato puree
# 1 (28 ounce) can diced tomatoes
# 1 (15 ounce) can tomato purée
# 8 grape tomatoes, halved
# 3 (14.5 ounce) cans Mexican-style stewed tomatoes
# 1 pound tomatoes, cored and quartered
# 2 ½ cups chopped tomatoes
# 4 large tomatoes, diced
# 1 (14.5 ounce) can Mexican-style stewed tomatoes
# 3 (14.5 ounce) cans diced tomatoes
# 1 (12 ounce) bottle tomato-based chili sauce
# 1 cup chopped roma (plum) tomatoes
# 1 cup diced tomato
# 1 cup cherry tomatoes, halved
# ½ cup diced tomatoes
# 1 tomato, chopped
# 1 cup cherry tomatoes, halved
# ½ cup tomato juice
# 1 (32 ounce) can canned diced tomatoes, undrained
# 1 (6 ounce) can tomato paste
# 1 medium tomato, sliced
# 1 (28 ounce) can diced tomatoes
# 1 (15 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 2 (15 ounce) cans tomato sauce
# 1 (6 ounce) can tomato paste
# 4 large tomatoes, chopped
# 2 cups tomato sauce
# 1 (16 ounce) can tomato sauce
# 1 pound tomatoes, coarsely chopped
# 2 fresh tomatoes, chopped
# 2 tomatoes, cubed
# 1 (16 ounce) can diced tomatoes
# 1 (15 ounce) can tomato sauce
# 1 (14.5 ounce) can diced tomatoes with garlic
# 1 (6 ounce) can tomato paste
# 1 tablespoon oil from sun-dried tomato jar
# 1/4 cup oil-packed sun-dried tomatoes
# 1 cup cherry tomatoes, halved
# 4 Roma tomatoes
# 1 small tomato
# 3 large tomatoes, sliced
# 1 (28 ounce) can crushed tomatoes
# 2 (14.5 ounce) cans diced tomatoes, undrained
# 3 tablespoons tomato paste
# ½ cup diced tomatoes
# 1 (14.5 ounce) can chopped tomatoes in puree
# 1 Roma tomato, diced
# 5 whole canned tomatoes, drained and chopped
# 1 (16 ounce) can tomato sauce
# 1 cup tomato paste
# 3 (29 ounce) cans tomato sauce
# 4 (6 ounce) cans tomato paste
# 1 cup tomato and clam juice cocktail
# 1 large tomato, peeled and chopped
# 1 (3.75 ounce) can sardines in tomato sauce
# 1 ½ cups canned peeled and diced tomatoes
# 1 cup tomato sauce
# 2 tablespoons oil from sun-dried tomato jar
# 1/3 cup coarsely chopped sun-dried tomatoes in oil
# 1 ½ tablespoons sun-dried tomato spread
# 1 (15 ounce) can diced tomatoes with green chile peppers
# 4 teaspoons tomato paste
# 1 small Roma tomato, chopped
# 10 cherry tomatoes, halved
# 5 cups crushed and strained tomatoes (such as Aurora®)
# 2 (10.75 ounce) cans tomato puree
# 1 (15 ounce) can tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 1 (16 ounce) can diced tomatoes
# ½ (8 ounce) can tomato paste
# 1 tablespoon tomato paste
# 1 large tomato, sliced
# 2 (14.5 ounce) cans diced stewed tomatoes with chili seasonings
# 1 (8 ounce) can tomato sauce
# 4 Roma tomatoes
# 1 (15 ounce) can Tex Mex-style diced tomatoes
# 1 tablespoon tomato paste
# 2 cups juicy chopped fresh tomatoes
# 2 tomatoes, chopped
# 6 roma (plum) tomatoes, chopped
# ½ cup sun-dried tomatoes, packed in oil
# 1 tablespoon tomato paste
# 1 (8 ounce) can tomato sauce
# 1 (28 ounce) can crushed tomatoes
# 6 Roma (plum) tomatoes, diced
# ¼ cup tomato sauce
# 1 tomato, diced
# 2 (28 ounce) cans crushed tomatoes with juice (such as Hunt's®)
# 1 (28 ounce) can Italian-style diced tomatoes (such as Hunt's® Diced Tomatoes with Basil, Garlic and Oregano)
# 1 (14.5 ounce) can crushed tomatoes
# 4 cups tomato juice
# 2 (14.5 ounce) cans stewed tomatoes
# ½ large tomato, diced
# 2 thin slices tomato, halved
# 2 (14.5 ounce) cans diced tomatoes with juice
# 2 (6 ounce) cans tomato paste
# 1 (8 ounce) can tomato sauce, or more if needed
# 4 fluid ounces tomato juice
# ¾ cup sun-dried tomatoes
# 1 (16 ounce) can diced tomatoes in juice
# 1 (10 ounce) can diced tomatoes and green chiles (such as RO*TEL®)
# 1 (10 ounce) can diced tomatoes with green chilies
# 1 tomato, chopped
# 1/4 cup tomato paste
# 2 (14.5 ounce) cans petite diced tomatoes
# 1 (8 ounce) can tomato sauce
# 1 cup diced petite-cut tomatoes
# 1 (28 ounce) can crushed tomatoes
# 1 (8 ounce) can tomato sauce
# 2 tomatoes, chopped
# 6 medium tomatoes, chopped
# 3 (15 ounce) cans tomato puree
# 2 (10.75 ounce) cans tomato puree
# 1 (10 ounce) can diced tomatoes with green chiles
# 4 medium Roma tomatoes
# 2 (10-ounce) cans diced tomatoes with green chilies,
# ½ cup chopped sun-dried tomatoes, divided
# 12 cherry tomatoes, halved
# 3 medium tomatoes, chopped
# 1 large tomato, peeled and chopped
# 2 (10 ounce) cans diced tomatoes with green chile peppers (such as Rotel)
# 1 (8 ounce) can tomato sauce
# 2 medium Roma tomatoes, chopped
# 1 cup tomato salsa
# ½ cup chopped sun-dried tomatoes, divided
# 3 medium chopped tomatoes
# 1 (8 ounce) can tomato paste
# 1 (32 ounce) can canned diced tomatoes, undrained
# 1 (6 ounce) can tomato paste
# 2 large tomatoes, diced
# 1 (8 ounce) can tomato sauce
# 1 pound tomatoes, cored and quartered
# ½ cup tomato sauce
# 1 (14.5 ounce) can diced tomatoes, drained
# 1 tomato, chopped
# 1 (46 fluid ounce) can tomato juice
# 1 (6 ounce) can tomato paste
# 1 small tomato, thinly sliced
# 1 (15 ounce) can stewed tomatoes
# 1 (8 ounce) can canned diced tomatoes
# 1 cup quartered cherry tomatoes
# 2 pints cherry or grape tomatoes
# 2 tablespoons sun-dried tomatoes
# 1 (10 ounce) can diced tomatoes with green chile peppers (such as RO*TEL®), drained
# 1 (15 ounce) can tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 1 tomato, diced
# 2 (28 ounce) cans tomato sauce (such as Hunt's®), divided
# 1 (10 ounce) can diced tomatoes
# ½ cup tomato paste
# 1 (10 ounce) can diced tomatoes with green chilies, drained
# 2 roma (plum) tomatoes, chopped
# 1 (14.5 ounce) can diced tomatoes
# 1 (15 ounce) can stewed tomatoes
# 2 tomatoes, diced
# 1 (14.5 ounce) can diced tomatoes, undrained
# 1 (15 ounce) can tomato sauce
# 1 medium tomato, sliced
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can tomatoes
# 1 ½ cups halved cherry tomatoes
# 1 pint cherry tomatoes, quartered
# 1 pint grape tomatoes
# 2 (14.5 ounce) cans Mexican-style stewed tomatoes
# 1/4 cup tomato paste
# 10 ripe tomatoes
# 1 (28 ounce) can tomato puree
# 1 (28 ounce) can diced tomatoes
# 1 pound tomatoes, coarsely chopped
# 4 roma (plum) tomatoes, seeded and chopped
# 3 Campari tomatoes, diced
# 2 medium Roma (plum) tomatoes, diced
# 1 (15 ounce) can whole peeled tomatoes, mashed
# 1 (28 ounce) can diced tomatoes
# 1 (14 ounce) can diced tomatoes, drained
# 1 (28 ounce) can Italian-style peeled tomatoes, crushed by hand
# 2 cups crushed tomatoes or tomato sauce
# 1 cup tomato salsa
# 3 roma tomatoes
# 8 roma (plum) tomatoes, diced
# 1 (8 ounce) can tomato sauce
# ½ cup diced tomatoes
# 2 (14.5 ounce) cans chili-seasoned diced tomatoes
# 1 (46 fluid ounce) can tomato juice
# 1 (29 ounce) can tomato sauce
# ½ tomato, diced
# 2 medium tomatoes, diced
# 5 ripe tomatoes
# 2 pounds green tomatoes, sliced
# ½ cup whole peeled tomatoes
# 1 (10.75 ounce) can condensed tomato soup, divided
# 6 Roma tomatoes, chopped
# 1 (10 ounce) can diced tomatoes with green chile peppers, drained
# 1 ½ cups cherry tomatoes, halved
# 1 (8 ounce) can tomato sauce
# 2 cups tomato sauce or tomato puree
# 2 (14.5 ounce) cans diced tomatoes
# 1 pound tomatoes, coarsely chopped
# 2 cups cherry tomatoes, seeded and diced
# 1 (16 ounce) can crushed tomatoes
# 1 (14.25 ounce) can tomato puree
# 1 medium tomato, diced
# 2 (28 ounce) cans tomato sauce
# 2 (6 ounce) cans tomato paste
# 1 cup canned diced tomatoes
# 2 tablespoons canned tomato paste
# 2 tomatoes, coarsely chopped
# 1 (6 ounce) can tomato paste
# 1 (32 ounce) jar roasted red pepper and garlic tomato sauce
# 3 tomatoes, chopped
# 3 (6 ounce) cans tomato sauce
# 2 tablespoons tomato paste
# 1 pound cherry tomatoes, halved
# 5 Roma tomatoes, diced
# 3 tomatoes, cored
# 2 medium tomatoes, chopped
# 3 Roma tomatoes, diced
# 2 pounds tomatoes - peeled, seeded, and coarsely chopped
# 2 (6 ounce) cans tomato paste with basil (such as Hunt's®)
# 1 (14.5 ounce) can diced tomatoes with jalapenos
# lettuce and tomato slices for serving
# 1 teaspoon tomato paste
# 1 (28 ounce) can diced tomatoes with juice
# 6 slices tomato
# 1 (15 ounce) can diced tomatoes, undrained
# 1 (15 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 2 (14.5 ounce) cans diced tomatoes
# 1 pint cherry tomatoes
# 1 cup cherry tomatoes, halved
# 2 Roma tomatoes, diced
# ¼ cup chopped sun-dried tomatoes
# 1 (14.5 ounce) can diced tomatoes
# 2 (6 ounce) cans tomato paste
# 1 cup Heinz tomato ketchup
# 1 1/2 cups cherry tomatoes
# 3 Roma (plum) tomatoes - peeled, seeded, and chopped
# 1 cup cherry tomatoes,
# 3 cups tomato pasta sauce
# 1 (8 ounce) can tomato sauce
# 1 (8 ounce) can stewed tomatoes, with liquid
# ½ cup sun-dried tomatoes, cut into thin strips
# 3 (12 ounce) cans tomato paste
# 3 tomatoes, diced
# 2 tablespoons finely chopped dried tomatoes
# 2 (14.5 ounce) cans diced tomatoes
# 1 (14.5 ounce) can stewed tomatoes
# 1 tablespoon tomato paste
# 2 cups chopped fresh tomato
# 2 cups chopped tomatoes
# 1 cup tomato sauce or marinara sauce
# 3 tomatoes, sliced
# 6 small tomatoes, halved
# 1 (14.5 ounce) can diced tomatoes
# 1 teaspoon tomato paste
# 1 small tomato
# 1 (10 ounce) can diced tomatoes and green chiles
# 2 (14.5 ounce) cans diced tomatoes
# 1 (15 ounce) can tomato sauce
# ½ cup diced tomato, divided
# 1 (10.75 ounce) can condensed tomato soup
# 2 (10 ounce) baskets cherry tomatoes
# 2 tablespoons tomato paste
# 1 (14.5 ounce) can crushed tomatoes, or coarsely chopped tomatoes packed in puree
# 1 (14.5 ounce) can Italian-style stewed tomatoes
# 1 (15 ounce) can Italian-style diced tomatoes
# 2 tablespoons tomato paste
# 1 can tomatoes
# 2 (12 ounce) bottles tomato-based chili sauce (such as Heinz)
# 1 (8 ounce) can tomato sauce
# 1 cup diced fresh tomato
# 3 cups diced tomatoes
# 1 (19 ounce) can diced tomatoes
# 1 chopped fresh tomato
# 3 cups chunky tomato sauce, divided
# 2 tomatoes, peeled and sliced
# 1 (14.5 ounce) can diced tomatoes, drained
# 3 (14.5 ounce) cans whole peeled tomatoes with liquid, chopped
# 10 ounces cherry or grape tomatoes
# 1/2 cup tomato
# 1 tablespoon tomato paste
# 2 ripe tomatoes, chopped
# ¼ cup tomato sauce
# 4 (15 ounce) cans tomato sauce
# 18 cherry tomatoes
# 1 small tomato, thinly sliced
# 1 (15 ounce) can tomato sauce
# 2 pints cherry tomatoes, quartered
# 1 ½ cups canned crushed tomatoes
# 1 (28 ounce) can diced tomatoes
# 4 slices tomato, or to taste
# 1 (14.5 ounce) can no-salt-added diced tomatoes with juices
# 3/4 cup grape tomatoes, halved
# 1 large tomato, diced
# 1 ½ pounds plum tomatoes, seeded and cut into small dice
# 3 cups freshly chopped tomatoes
# 2 tomatoes
# 1 Roma tomato, seeded and finely chopped
# 1 tablespoon tomato paste
# 2 ripe tomatoes, seeded and chopped
# 1 (29 ounce) can tomato puree (such as Contadina® Tomato Puree)
# 1 (14.5 ounce) can chili-style diced tomatoes
# 1 small tomato, chopped
# 1 (8 ounce) can tomato sauce
# 1 tablespoon tomato paste
# 1 (8 ounce) can tomato sauce
# 1 large tomato, chopped
# 4 tablespoons tomato paste
# 2 tomatoes, diced
# 1 (6 ounce) can tomato paste
# 2 (28 ounce) cans whole tomatoes, undrained and chopped
# 1 (15 ounce) can tomato sauce
# 1 (6 ounce) can tomato paste
# 1 (28 ounce) can crushed tomatoes
# 1 tomato, quartered
# 4 ripe tomatoes, diced
# ½ cup tomato paste
# 1 (14.5 ounce) can diced tomatoes
# 1 cup tomato sauce, divided
# 1 large tomato, cut into 8 slices
# 6 grape or cherry tomatoes
# 3 tablespoons sun-dried tomatoes packed in oil, drained and chopped
# 1 (14.5 ounce) can stewed tomatoes
# ½ tomato, diced
# 1 tablespoon tomato paste
# 2 ½ cups tomato sauce
# 2 medium tomatoes, chopped
# 1 (28 ounce) can diced tomatoes with juice
# 1 (15 ounce) can tomato sauce
# 1 (15 ounce) can tomato sauce
# 1 (14.5 ounce) can diced tomatoes
# 1 (14.5 ounce) can fire-roasted tomatoes
# 2 Roma tomatoes
# 2 (14.5 ounce) cans diced tomatoes with green chile peppers
# 1 (14.5 ounce) can diced tomatoes
# 1 (8 ounce) can tomato sauce
# 1 tablespoon tomato paste
# 1/2 cup tomato
# 8 cherry tomatoes, quartered
# 1 (14.5 ounce) can diced tomatoes
# 1 large tomato, chopped
# 1 (6 ounce) tub sun-dried tomato pesto
# 2 roma (plum) tomatoes, chopped

# %%
@dataclass
class Recipe:
    category: str
    title: str
    ingredient_list: list[str]
    directions: list[str]

# %%
import re

MEASUREMENT_WORDS = {
    "can", "cup", "cups", "ounce", "ounces", "tablespoon", "tablespoons", "tsp",
    "tbsp", "teaspoon", "teaspoons", "tablespoon", "tablespoons", "oz",
    "pound", "pounds", "lb", "lbs", "gram", "grams", "kilogram", "kg",
    "ml", "liter", "liters", "pinch", "dash"
}

DESCRIPTIVE_WORDS = {
    "small", "medium", "large", "chopped", "minced", "frozen", "quart", "frying",
    "thin", "strips", "cut", "cleaned", "scaled", "peeled", "taste", "freshly", "ground",
    "seeded", "sliced", "fresh", "stripped", "cracked", "softened", "finely", "diced", "ripe",
    "pitted", "thinly", "crushed", "unbaked", "miniature", "julienned", "cooled", "drained", "rinsed",
    "divided", "stemmed", "bottled", "package", "shredded", "heated", "bite-sized", "pieces",
    "thawed", "uncooked", "jar", "caps", "slices", "dice", "matchsticksize", "lengths", "cubes", "thickly",
    "homemade", 
}


STOP_WORDS = {
    "of", "and", "for", "to", "into", "or", "more", "optional", "as", "needed", "per", "deveined",
    "inch", "such", "degrees", "f", "c", "container", "if", "enough", "cover", "removed", "bags", "the"
}

def clean_ingredient(ingredient: str):
    ingredient = ingredient.lower()

    # Remove punctuation and numbers
    ingredient = re.sub(r"[\'\-\(\)\/\d\.,⅛¼⅓½⅔¾™]+", "", ingredient)

    measurement_pattern = r"\b(" + "|".join(MEASUREMENT_WORDS) + r")\b"
    descriptive_pattern = r"\b(" + "|".join(DESCRIPTIVE_WORDS) + r")\b"
    stopword_pattern = r"\b(" + "|".join(STOP_WORDS) + r")\b"

    ingredient = re.sub(measurement_pattern, "", ingredient)
    ingredient = re.sub(descriptive_pattern, "", ingredient)
    ingredient = re.sub(stopword_pattern, "", ingredient)

    return ingredient.strip()


ingredients = df["ingredients"]
unique_ingredients = set()


for ingredient_list in ingredients:
    for ingredient in ingredient_list:
        ingredient = clean_ingredient(ingredient)
        unique_ingredients.add(ingredient)

# %%
unique_ingredients
# Out:
# {'',
#  'shoestring fries',
#  'onion green bell pepper  celery mix',
#  'dry green lentils',
#  'strawberry halves',
#  'castelvetrano olives   dried',
#  'fluid  bottle apple cider',
#  'lean breakfast turkey sausage links',
#  'homemade chicken broth  lowsodium canned broth',
#  'spicy brown mustard',
#  'green grapes   garnish',
#  'loaf   white bread',
#  'salmon fillets',
#  'cooked green lentils',
#  'boneless beef sirloin  beef top round steaks " thick',
#  'unsweetened coconut milk wellshaken   thai kitchen',
#  'whole bran cereal',
#  'apple sauce  plum preserves  serving',
#  'fireroasted  green chile peppers',
#  'sugarfree vanilla extract',
#  'chile pepper',
#  'mashed avocado from mexico',
#  'bunch  spinach   torn  bitesized',
#  'red bell pepper   bitesize',
#  'jars prepared pasta sauce',
#  'green garlic garlic scapes',
#  'extravirgin olive oil plus   garnish',
#  'fluid  jigger vodka',
#  'skinless boneless chicken breast halves pounded',
#  'black forest ham',
#  'white onions halved     rings',
#  'microwavable white rice   uncle bens crumbled',
#  'caesar salad croutons',
#  'cauliflower florets broken  bite size',
#  'boneless skinless chicken breast tenders',
#  'leaves romaine  leaf lettuce',
#  'bunch  asparagus',
#  'potato rounds   oreida® crispy crowns®',
#  'round gyozapotsticker wrappers',
#  'goya sazonador total',
#  'endive spears  garnish',
#  'fluid    juice concentrate  any flavor except citrus',
#  'packages refrigerated biscuit dough separated    quarters',
#  'ginger paste',
#  'torn dandelion greens',
#  'drops grenadine syrup',
#  'roasted salted pistachios',
#  'canned water chestnuts',
#  'flaxseed oil',
#  'ouncesground beef andor bulk i  beef andor bulk i',
#  'fish sauce',
#  'pepitas pumpkin seeds',
#  'lime juice from   limes',
#  'swiss cheese about  thick',
#  'cherry wood chips',
#  'roughly  pickled cauliflower florets',
#  'selfrising cornbread mix   martha white®',
#  'thick boneless pork loin chops',
#  '⅜  halved candied cherries',
#  'yam',
#  'steak seasoning rub',
#  'sundried tomatoes not packed in oil snipped',
#  'chickpeas half  liquid reserved',
#  'unpeeled peaches   coarsely',
#  'barbeque sauce   sweet baby rays® hickory & brown sugar',
#  'saigon cinnamon',
#  'sweet potatoes   coarsely',
#  'bunch  cilantro leaves  stems',
#  'dried  rosemary',
#  'roma plum tomatoes halved lengthwise',
#  'cans  green chilies',
#  'dole® pineapple juice',
#  'leftover pulled pork',
#  'white vinegar',
#  'cooked carrot',
#  'sweet potatoes  jewel yams',
#  'carrots halved lengthwise   crosswise',
#  'ranch dressing  blue cheese dressing  serving',
#  'almond paste',
#  'reynolds wrap® aluminum foil',
#  'white grape juice',
#  'wholeberry cranberry sauce',
#  'country sausage',
#  'ouncebonein doublecut p bonein doublecut p',
#  'milliliter bottle white rum',
#  'apple without peel',
#  'country crock® spread melted',
#  'eggs separated  at room temperature',
#  'bottle bbq sauce',
#  'dry ranch dressing mix',
#  'cooked  chicken breast meat',
#  'red potatoes   chunks',
#  'lightly smoked cod skin  bones',
#  'queso quesadilla mexican melting cheese',
#  'packages   spinach    squeezed dry',
#  'thick  chunky salsa',
#  'smoked paprika  garnish',
#  'butter   pats',
#  'bunch spinach tough stems',
#  'delistyle turkey',
#  'nestle carnation sweetened condensed milk',
#  'plus   powdered sugar',
#  'korean chili pepper flakes',
#  'prepared hot horseradish',
#  'bunch scallions',
#  'split bengal  chana dal',
#  'cinnamon graham cracker sticks   boneshaped scoobydoo snacks',
#  'whole  black olives',
#  'lightly packed fine almond flour',
#  'harissa powder',
#  'granulated coconut sugar',
#  'smuckers caramel flavored topping',
#  'whole wheat couscous',
#  'banana ketchup',
#  'shrimp       bitesized',
#  'white  portobello mushrooms',
#  'blackberry juice',
#  'pillsbury grands! refrigerated biscuits',
#  'goya adobo with pepper plus',
#  'your favorite bloody mary mix  make your own below',
#  'green olives   halved',
#  'head cauliflower trimmed    bitesize florets',
#  'cans  white potatoes',
#  'skinless boneless chicken breast halves   in half',
#  'multigrain toasted oat cereal   cheerios®',
#  'strong espresso coffee',
#  'vanilla sugar',
#  'boneless pork shoulder roast',
#  'sea salt gray',
#  'roquefort cheese crumbled',
#  'vanillaflavored candy coating',
#  'eggnog',
#  'quarts water  amount',
#  'thick  italian bread',
#  'skirt steak',
#  'fl  cans chunk chicken breast   flaked',
#  'sea scallops   thirds',
#  'mixed  berries',
#  'string beans',
#  'grated zest  one lemon',
#  'centercut bacon  in half crosswise',
#  'beef cube steak',
#  'black forest ham  in half',
#  'uncrustables sandwiches',
#  'snipped chives',
#  'honey  maple syrup',
#  'reducedfat sour cream',
#  'bulb  fennel white part only',
#  'bottles cream soda',
#  'cold salted butter cubed',
#  'roasted garlic spaghetti sauce   barilla',
#  'oreo cookies',
#  'filtered water',
#  'pineapple cored',
#  'creamy italian salad dressing',
#  'red bell pepper      squares',
#  'broken dried mushrooms',
#  'bacon   thirds',
#  'coconut flavoring',
#  'stick   very cold butter',
#  'red grapefruit juice',
#  'light soy sauce',
#  'coarsely  peanuts',
#  'white radishes labanos',
#  'mashed banana',
#  'chile de arbol peppers',
#  'beef tenderloin filets',
#  'chickpeas  with liquid reserved',
#  'light ricotta cheese',
#  'multicolored candy sprinkles jimmies  desired',
#  'tuna packed in olive oil',
#  'tater tots about',
#  'coconut flour sifted',
#  'grated manchego cheese',
#  'sundried tomato paste',
#  'crumbled sheeps milk feta cheese',
#  'packages tricolor pasta',
#  'flank steak pounded until',
#  'old el paso® taco seasoning mix from',
#  'english cucumber quartered',
#  'yellow onion    thick rings',
#  'fluid  coffeeflavored liqueur   kahlua®',
#  'prepared polenta',
#  'packages firm tofu',
#  'quartered  mushrooms',
#  'beer',
#  'sriracha  other hot sauce',
#  'trimmed skirt steaks',
#  'nonchlorinated water',
#  'seedless green grapes',
#  'italian tipo "" flour',
#  'plus   olive oil',
#  'chocolate instant pudding mix',
#  'pint cherry tomatoes halved',
#  'peaches   halved',
#  'smokehouse maple seasoning   mccormick® grill mates®',
#  'packet hidden valley® original ranch® salad dressing & seasoning mix',
#  'shrimp peelend',
#  'pure almond extract',
#  'dry french onion soup mix',
#  'liquid hot pepper sauce   tabasco',
#  'beef eye  round',
#  'sweet potato starch',
#  'fluid   nestle carnation evaporated milk',
#  'packages dried udon noodles',
#  'restaurantstyle tortilla chips',
#  'garlic clove   very',
#  'bunch celery   bitesized',
#  'roasted red bell peppers in water',
#  'stew beef',
#  'nama shoyu raw soy sauce',
#  'o ld bay seasoning',
#  'brie cheese    squares',
#  'jars marinara sauce   classico tomato  basil',
#  'sea salt   maldon',
#  'spaghetti squash about    halved',
#  'elbow macaroni cooked',
#  'triangular slice watermelon',
#  'dry red wine   pinot noir  chianti',
#  'loaves  bread dough',
#  'venison tenderloin roasts',
#  'packages doublecrust pie pastry',
#  'spicy chili crisp sauce',
#  'kimchi   bitesized',
#  'maraschino cherries  garnish',
#  'refried black beans',
#  'leftover  turkey',
#  'italian seasoned bread crumbs',
#  'roma plum tomatoes',
#  'applesauce   motts®',
#  'fluid    bottle beer',
#  'extra lean  turkey',
#  'cold butter',
#  'packet ranch dip mix',
#  'ube flavoring  extract',
#  'red potatoes',
#  'haddock fillets',
#  'fluid  espresso',
#  'strawberry nectar   jumex®',
#  'peach juice',
#  'wooden paint stir sticks',
#  'chaat masala',
#  'red bell pepper   matchsticks',
#  'baking mix   bisquick®',
#  'hawaiian sweet rolls',
#  'head cabbage   eighths',
#  'cubed butternut squash',
#  'squares semisweet chocolate coarsely grated',
#  'russet potatoes cubed',
#  'several  thyme',
#  'pink lemonade from concentrate',
#  'lite soy sauce',
#  'piece ginger grated',
#  'white sugar     rimming',
#  'key lime zest',
#  'z',
#  'cans pinto beans    well',
#  'lingonberries',
#  'stuffed green olives',
#  'carrot  diagonally  thick',
#  'snipped  basil',
#  'pineapple chunks in % pineapple juice',
#  'broccoli flowerets',
#  'yellow squash halved',
#  'packed dried apricots',
#  'yukon gold potatoe',
#  'fluid  seltzer water',
#  'egglands best eggs',
#  'maple sugar',
#  'hatch chile peppers halved',
#  'instant coffee   folgers®',
#  'pandan leaf',
#  'quarts clam juice',
#  'potato starch',
#  'spaghetti pasta',
#  'cooked carrots',
#  'cold strong coffee',
#  'bosc pears  cored  stems left on',
#  'melted butter  oil',
#  'brown sugar light  dark',
#  'salami     each',
#  'asian chile pepper sauce   sambal oelek',
#  'fine sea salt',
#  'wedge lime  garnish',
#  'skinless boneless chicken breast halves    wide',
#  'crostini  serving',
#  'baby bella crimini mushrooms',
#  'mini candycoated chocolates',
#  'fluid  amber rum',
#  'carrot    julienne',
#  'italian plum tomatoes',
#  'sauvignon blanc wine',
#  'gruyère cheese',
#  'grilled chicken breasts   bitesized',
#  'pint raspberries',
#  'eggplants  lengthwise  ⁄',
#  'box fettuccine noodles',
#  'prepared chocolate crumb crust',
#  'lemon  herb seafood seasoning',
#  'steak seasoning   dales®',
#  'crumbled dried oregano',
#  'crystallized ginger',
#  'riracha hot sauce',
#  'dried cranberries*',
#  'semisweet chocolate   guittard®',
#  'endive',
#  'papaya',
#  'mesquitesmoked turkey breast',
#  'unopened oysters',
#  'creamy goat cheese',
#  'jumbo raw shrimp    tails left on',
#  '⅜  buttermilk',
#  'head bok choy',
#  'dark sweet cherries',
#  'heads baby bok choy',
#  'water chestnuts',
#  'bunches curly kale',
#  'lowersodium beef broth',
#  'envelope chicken taco seasoning mix   mccormick®',
#  'wholegrain  challah bread',
#  'herbseasoned stuffing mix   pepperidge farm herbseasoned stuffing',
#  'dark rum   meyers®',
#  'ricotta cheese well',
#  'refrigerated cinnamon rolls with icing   pillsbury® refrigerated cinnamon rolls with icing',
#  'bananas pureed',
#  'seedless grapes halved',
#  'packages refrigerated gnocchi',
#  'angel hair pasta',
#  'sprinkles',
#  'luid ounc triple sec',
#  'turkey pan drippings fat skimmed',
#  'korean red pepper flakes gochugaru',
#  'masa harina',
#  'milliliter bottle  proof grain alcohol   everclear®',
#  'cans yams in syrup',
#  'buttery crackers   keebler club® crackers',
#  'oil  vinegar salad dressing   newmans own',
#  'pastrami',
#  'mild cheddar  fontina cheese',
#  'glutenfree gingersnap cookies',
#  'snipped  rosemary',
#  'packages little smokie sausages',
#  'prepared pizza sauce',
#  'strawberry syrup   torani®',
#  'honey butter',
#  'egg yolk',
#  'drops food coloring any color',
#  'chocolatehazelnut spread   nutella at room temperature',
#  'spice islands®  red pepper',
#  'lemons juiced  zested',
#  'bosc pears  with stems intact',
#  'dashes bitters   angostura',
#  'bunches collard greens',
#  'lemon juice  less',
#  'bonito flakes',
#  'cremini mushrooms  baby bellas',
#  'jalapeño peppers   inchthick rings',
#  'desired fillings see bottom  recipe',
#  'cajun seasoning   tony chacheres®',
#  'crumbled greek feta',
#  'tart cherries in water',
#  'cream cheese flavored frosting   betty crocker® rich  creamy',
#  'cans  tomatoes with green chile peppers',
#  'prune juice',
#  'peppercorns',
#  'salt   pepper',
#  'cans  tomatoes with garlic  oregano',
#  'plain fatfree greek yogurt',
#  'naturally flavored strawberry yogurt',
#  'honeycrisp apples  cored  quartered',
#  'box noboil lasagna noodles',
#  'fluid   ale',
#  'chilistyle  tomatoes',
#  'reducedfat sharp cheddar cheese',
#  'cans nosaltadded navy beans',
#  'tricolored pasta assortment',
#  'raw crawfish',
#  'patties  beef',
#  'pepperoni each piece',
#  'fillets walleye',
#  'unsalted butter melted  slightly',
#  'shelled unsalted sunflower seeds',
#  'cubed  zucchini',
#  'pie crust dough pastry  a doublecrust  pie',
#  'sleeve buttery round crackers   ritz',
#  'hardboiled egg halved',
#  'refrigerated pie pastry',
#  'lemonflavored ice tea mix',
#  'baby red potatoes quartered',
#  'pints orange sherbet',
#  'ditalini  other  pasta',
#  'fluid  jigger peach schnapps',
#  'torn arugula leaves',
#  'pouch liquid pectin',
#  'marinara sauce plus   serving',
#  'seasoned cornbread stuffing mix',
#  'packages noninstant chocolate pudding mix',
#  'old fashioned oats',
#  'vegan buffalo wing sauce   franks®',
#  'mccormick®  nutmeg',
#  'ginger plus   garnish',
#  'fine dry bread crumbs',
#  'mexican cheese',
#  'raw jumbo shrimp shelled',
#  'packages dry mexican  taco seasoning',
#  'long grain  wild rice mix with seasoning packet',
#  'fluid  red wine',
#  'hummus spread',
#  'bread broken up',
#  'brown roux',
#  'lemon verbena leaves',
#  'beets  with liquid reserved',
#  'bonein goat shank',
#  'soft silken tofu',
#  'beef tenderloin steaks',
#  'condensed cream  mushroom soup   campbells',
#  'bunch beet greens',
#  'milk at room temperature',
#  'hot cooked regular longgrain white rice',
#  'strawberries hulled   berries  in half',
#  'bonein lamb chops',
#  'dry  elbow macaroni',
#  'toffee chips',
#  'cooked lobster meat',
#  'vegetable bouillon',
#  'whole chicken bones  skin',
#  'bunch scallions   dark green parts set aside',
#  'cubed cooked ham',
#  'carrots   bitesized',
#  'mild pork sausage   jimmy dean®',
#  'unflavored gelatin   knox',
#  'sheet seaweed torn',
#  'spice islands® poppy seed',
#  'powdered buttermilk',
#  'basmati rice  other long grain white rice',
#  'arge egg yolks',
#  'gallons cold water',
#  'grated parmesanstyle vegan cheese   follow your heart®',
#  'bag corn chips   fritos®',
#  'italian plum tomatoes halved',
#  'mascarpone cheese',
#  'stick salted butter',
#  'bottle vodka',
#  'sage leaf',
#  'amish friendship bread starter',
#  'dashes  black pepper',
#  'splash water',
#  'packed light brown sugar',
#  'burger toppings  choice',
#  'corn chips',
#  'lowersodium pasta sauce',
#  'asiago cheese',
#  'whole baby carrots',
#  'unsalted raw pumpkin seeds',
#  'red potatoes with peel',
#  'apple cored',
#  'vinegar  lemon juice',
#  'allpurpose baking mix   bisquick®',
#  'cans chunk light tuna in water',
#  'unpeeled red potatoes',
#  'white peaches     bitesized',
#  'fillets mahi mahi',
#  'chickens each',
#  'serrano pepper   desired',
#  'olive oilpacked tuna oil reserved',
#  'packages white chocolate chips',
#  'broccoli stalks coarsely',
#  'leek white parts only quartered lengthwise',
#  'milk chocolate chips andor white chocolate chips',
#  'italianstyle  tomatoes undrained',
#  'bunch  spinach',
#  'colored sugar  decoration',
#  'salted cashews',
#  'cans spicy chili beans',
#  'bottle hot pepper sauce   tabasco',
#  'squid     rings',
#  'packet beef stroganoff sauce seasoning',
#  'calabrian chili peppers in oil',
#  'heads cabbage cored    long  shreds',
#  'hot sauce   louisiana®',
#  'prosciutto roughly torn',
#  'cheese filled spinach ravioli',
#  'french bread toasted',
#  'apple   matchsticks',
#  'loosely packed  parsley leaves',
#  'whole onion',
#  'raw  shrimp',
#  'refrigerated biscuit dough baked according   instructions',
#  'onion buns',
#  'ranch style beans',
#  'bamboo skewers',
#  'almond milk   silk®',
#  'grilled vegetarian burger patties',
#  'eggplant ends trimmed',
#  'multigrain sandwich rolls   sandwichthins®',
#  'button mushrooms coarsely',
#  'chocolate frosting',
#  'cans crescent dough sheets',
#  'beef chuck roast trimmed  excess fat',
#  'bitesize broccoli',
#  'sucralose sugar substitute   splenda®',
#  'dashes hot pepper sauce',
#  'jarred jalapeno pepper',
#  'brewed espresso',
#  'heads napa cabbage cored    quarters lengthwise',
#  'bunch  rosemary',
#  'mixed baby salad greens',
#  'slice sweet onion',
#  'poundschicken breast chicken breast',
#  'slice  ginger root',
#  'beef pot roast fat trimmed  discarded',
#  'mustard seeds',
#  'asparagus stalks trimmed',
#  'easpoons vanilla extract',
#  'ghirardelli grand semisweet chips',
#  'bottle lager beer   corona',
#  'chilled sparkling wine',
#  'skinless boneless chicken breast   bitesized chunks',
#  'boneless butterflied leg  lamb trimmed',
#  'golden delicious apple   cored',
#  'roughly  parsley',
#  'irish cream liqueur eg baileys®',
#  'unpeeled ginger root    chunks',
#  'cooked shrimp',
#  'nosaltadded chicken broth',
#  'sorghum flour',
#  'brown gravy mix',
#  'juice from canned pineapple',
#  'fluid  jigger sweet  sour mix',
#  'tomatoes halved lengthwise',
#  'agave nectar',
#  'everything bagel thins',
#  'green bell pepper   squares',
#  'rotisserie chicken boned  cubed',
#  'boneless skinless chicken breast halves   bitesized',
#  '⅜  shortening',
#  'rum flavored extract',
#  'cucumber shaved',
#  'adobo sauce from chipotle chile peppers',
#  'genoa salami',
#  'tabasco®',
#  'canning salt',
#  'cognac  brandy',
#  'green jalapeno peppers',
#  'crimini mushrooms stems',
#  'reducedsodium chicken broth',
#  'vidalia  sweet onion      wedges',
#  'mexicanstyle hot tomato sauce',
#  'packed  sweetened coconut',
#  'shaoxing wine chinese rice wine',
#  'glutenfree allpurpose baking flour',
#  'thigh with skin chicken',
#  'cinnamon plus   dusting',
#  'precooked smoked sausage   sixteen',
#  'lobster tails split in half lengthwise',
#  'shelled roasted sunflower seeds',
#  'skinless cod fillets',
#  'belacan malaysian chileshrimp paste',
#  'butter  greasing',
#  'storebought meringue cookies',
#  'carton beef broth',
#  'gay lea sour cream',
#  'fireroasted tomatoes   hunts®',
#  'packages refrigerated crescent roll dough   pillsbury®',
#  'dried linguine pasta',
#  'reynolds parchment paper',
#  'pig tails',
#  'chicken breast cubed',
#  'tom yum paste',
#  'reducedsodium dill pickle chips',
#  'creole mustard',
#  'pineapple well',
#  'cabbage slaw mix',
#  'ancho chiles',
#  'white button mushrooms',
#  'boneless new york strip steaks',
#  'barbeque sauce   sweet baby rays®',
#  'fajitasize flour tortillas',
#  'chunks  celery',
#  'skinon bonein whole chicken legs drumsticks  thighs',
#  'extra virgin olive oil  drizzling',
#  'bag ravioli',
#  'fluid  rock candy syrup',
#  'cooked prawns',
#  'yellow bell pepper   bitesize',
#  'bacon fat melted',
#  'carrots    in chunks',
#  'garden rotini pasta',
#  'sweetened flaked coconut',
#  'tater tots',
#  'salt   black peper',
#  'bitesized potato nuggets tater tots®',
#  'box moist pineapple cake mix',
#  'milk chocolate melted',
#  'kraft % milk  sharp cheddar cheese',
#  'dried  shallots',
#  'cooked rice  serving',
#  'lavash  other flatbread',
#  'yellowtail flounder',
#  'morel mushrooms',
#  'box cornbread mix',
#  'milliliter bottle prosecco',
#  'fluid  bubblegumflavored vodka',
#  'shaved pecorino romano cheese  garnish',
#  'grated asian pear',
#  'leeks bulb only   rings',
#  'white teff flour',
#  'bunch kale stems   discarded',
#  'trimmed brussels sprouts',
#  'roasted red peppers in oil with garlic',
#  'dry great northern beans sorted',
#  'kim milk',
#  'red onion  in half',
#  'assorted light food dye',
#  'kraft grated parmesan cheese',
#  'packages smoked kielbasa sausage',
#  'fluid  bottle mexican beer',
#  'white lily all purpose wheat flour',
#  'bottles italianstyle salad dressing',
#  'stalk celery  garnish',
#  'fresno chile peppers   rings',
#  'butterflavored vegetable shortening',
#  'caribbean jerk seasoning',
#  'cans refrigerated biscuit dough separated',
#  'box vanilla wafer cookies',
#  'strong hot brewed coffee',
#  'blood oranges juiced',
#  'light  nonfat mayonnaise',
#  'pint sour cream',
#  'ginger stirin paste',
#  'prosciutto   chunks',
#  'bosc pear',
#  'vanilla fatfree yogurt',
#  'bunch cilantro stems  leaves separated',
#  'white cake mix extender see cooks note',
#  'bacon   in half',
#  'powdered egg substitute',
#  'confectioners sugar plus',
#  'cans chili with beans',
#  'ravy',
#  'jalapeño salsa   el pato®',
#  'bottle chilled lemonlime soda',
#  'green peas  well',
#  'packages colbyjack cheese',
#  'sweetened condensed milk',
#  'deli ham  in half',
#  'pineapple  orange   garnish',
#  'agave',
#  'fluid  peanut butter whiskey',
#  'spinach well washed',
#  'piece  ginger   smashed',
#  'russels sprouts',
#  'warm water     ;',
#  'dried red chile peppers   cayenne',
#  'butternut squash   cubed',
#  'tamarind juice',
#  'firm green pears   cored  halved',
#  'ear corn kernels  from  cob',
#  'roma tomato  lengthwise',
#  'soy sauce  dipping',
#  'head  broccoli   florets',
#  'chickenflavored ramen noodle seasoning packets',
#  'ritz crackers',
#  'refrigerated french bread dough',
#  'sirloin lamb chops room temperature',
#  'limes   wedges  garnish',
#  'chocolate creme eggs',
#  'bottle heinz® chili sauce chunky with sweet peppers',
#  'orange bell pepper',
#  'packages ramen',
#  'beets boiled  grated',
#  'cans blackeyed peas',
#  'black  red pepper blend   mccormick® hot shot®',
#  'orange jam',
#  'cream  coconut   coco lopez',
#  'romano cheese grated',
#  'candy canes',
#  'chorizo',
#  'fluid  hard apple cider',
#  'curing salt prague powder #',
#  'marinated artichoke hearts  liquid reserved',
#  'leftover rotisserie chicken',
#  'nameko mushrooms trimmed',
#  'asian chili black bean sauce',
#  'hatch green chiles',
#  'lime zest',
#  'hatch new mexico green chile peppers',
#  'carnaroli  arborio rice',
#  'fillets beef tenderloin',
#  'wheat berries',
#  'prepared sponge cake dessert',
#  'talian bread crumbs',
#  'assorted bell peppers   yellow green  red',
#  'liquid rennet',
#  'packages baby bella  domestic white mushrooms',
#  'yellow onions halved     thick',
#  'pickled jalapeno peppers  juice',
#  'lowsodium vegan vegetable broth',
#  'pie crust see footnote  recipe link',
#  'pods star anise',
#  'chocolate hazelnut spread   nutella®',
#  'carrots about',
#  'ball  mozzarella cheese',
#  'quarts halfandhalf',
#  'canola oil  extra virgin olive oil',
#  'adobo sauce from canned chilies',
#  'coarsely   ginger',
#  'sambal oelek chili paste',
#  'rome beauty apples   cored  cubed',
#  'extralean %  beef',
#  'buffalo wing sauce   sweet baby rays®',
#  'chard with stems',
#  'mint',
#  'clams in shell',
#  'packages raspberryflavored gelatin   jello',
#  'roasted pine nuts',
#  'whole cooked chicken deboned',
#  'poblano chile',
#  'butterflavored cooking spray   pam',
#  'dry linguine pasta',
#  'butternut squash quartered',
#  'packet carnation breakfast essentials® rich milk chocolate powdered drink mix',
#  'mexican style hot tomato sauce   el pato salsa de chile fresco®',
#  'french bread hoagie rolls',
#  'prepared sausage gravy',
#  'tomato  clam juice cocktail   clamato®',
#  'prepared pastry dough   pie',
#  'head butter lettuce',
#  'major grey chutney',
#  'queso asadero white mexican cheese',
#  'cans refrigerated sweet roll dough',
#  'strawberries hulled  quartered',
#  'italian five cheese blend  cheese',
#  'ginger ale chilled',
#  'toasted oat cereal rings   cheerios®',
#  'fluid  coconutflavored rum   malibu®',
#  'packages firm tofu cubed',
#  'nacho cheeseflavored chips',
#  'tomatobased chili sauce',
#  'pressurized whipped cream',
#  'grated parmesanromano cheese',
#  'avocado     mashed',
#  'cans  tomatoes  green chiles   ro*tel',
#  'brownie mix without nuts',
#  'bulk hot pork sausage',
#  'nacho cheeseflavored corn chips   doritos®',
#  'fillet cooked prime rib   bitesize',
#  'purchased guacamole',
#  'tart apple   grated',
#  'colby longhorn cheese',
#  'toasted sesame seeds',
#  'mozzarellastyle vegan cheese   daiya®',
#  'processed cheese food   velveeta ®',
#  'reducedfat cheddar cheese',
#  'multicolored sweet peppers',
#  'dark chocolate chips   ghirardelli®',
#  'cans white beans',
#  'spinach not',
#  'pints whole milk',
#  'coarsely  garlic',
#  'whole cardamom pod',
#  'salt added canned black beans',
#  'prepared thai peanut sauce',
#  'piloncillo mexican brown sugar cones',
#  'plus   tapioca starch',
#  'tomato   wedges',
#  'whole cranberries',
#  'swanson chicken broth',
#  'drop red food coloring  desired amount',
#  'chocolatecovered peanut butter    reeses unwrapped',
#  'chestnut flour',
#  'bay  sea scallops',
#  'ears corn kernels  from cob',
#  'dry yellow lentils',
#  'bottle lemonlime flavored carbonated beverage',
#  'queso fresco crumbled',
#  'red fresno chile pepper  very',
#  'vegetable oil spray',
#  'rigatoni pasta cooked',
#  'dried marjoram  thyme',
#  'pint extra virgin olive oil',
#  'italian prune plums halved',
#  'tri tip roast',
#  'bottle ketchup',
#  'envelope unflavored gelatin',
#  'ranch dressing  seasoning mix',
#  'refried beans',
#  'spears  asparagus trimmed',
#  'german wiener  vienna sausages',
#  'bottle apple ale   reds®',
#  'veal knuckle',
#  'carrots     bitesize',
#  'cold cooked white rice',
#  'bell peppers    in',
#  'packet chicken noodle soup mix',
#  'pork butt shoulder roast',
#  'oil from sundried tomatoes',
#  'fluid  limoncello',
#  'chile powder',
#  'roast beef',
#  'soybean oil',
#  'cooked rice  pasta',
#  'nostick cooking spray',
#  'extra sharp cheddar cheese',
#  'bunch swiss chard stalks discarded leaves   wide ribbons',
#  'cooked  ham',
#  'broccoli  cheese flavored rice mix',
#  'organic tomato sauce',
#  'roasted sesame seeds',
#  'boneless skinless chicken breast  in bitesized',
#  'wax beans trimmed  snapped',
#  'shiitake mushrooms  in half',
#  'packages canadian bacon quartered',
#  'dry ramen noodles',
#  'pork sausage patties',
#  'slice white sandwich bread',
#  'apples   cored    wedges',
#  'sake japanese rice wine',
#  'bag sour creamandonionflavored potato chips',
#  'fluid  chilled dry sparkling wine',
#  'peanuts roughly',
#  'fluid  jigger cointreau',
#  'toasted black sesame seeds',
#  'skinless peanuts',
#  'fluid  coffee flavored liqueur',
#  'scoop vanilla bean ice cream',
#  'whole  tomatoes',
#  'boneless beef sirloin',
#  'gruyère  comté cheese',
#  'sprigs  parsley',
#  'seedless watermelon chilled',
#  'crispy chicken   chicken fingers cooked',
#  'lasagna ovenready',
#  'cans  tomatoes with green chile peppers   ro*tel®',
#  'red food coloring',
#  'fully cooked luncheon meat eg spam cubed',
#  'cellophane noodles soaked in warm water',
#  'puffed wheat cereal',
#  'red bell pepper    chunks',
#  'cans condensed cream  mushroom soup',
#  'jalapeno pepper with stem',
#  'butternut squash    cubed',
#  'round brie cheese    chunks',
#  'carrots    fourths then  lengthwise',
#  'garam masala indian spice blend',
#  'goodquality unsweetened cocoa powder sifted',
#  'parmigiano reggiano cheese grated',
#  'granny smith apple    thick rounds',
#  'granola   desired',
#  'cacho de cabra pepper  anaheim pepper',
#  'smoked almonds',
#  'acorn squash',
#  'prepared mincemeat',
#  'cans sweetened cream  coconut   coco lopez®',
#  'red thai chile pepper',
#  'grilled skinless boneless chicken thighs',
#  'box vanilla wafer cookies   nilla',
#  'rolo candies',
#  'bunch broccoli   chunks',
#  'cinnamon  dusting',
#  'cans lowsodium canned luncheon meat   spam',
#  'combination  dried fruit   prunes apricots pears  apples',
#  'crackers   wheatsworth®',
#  'head cabbage  washed cored quartered',
#  'containers ricotta cheese',
#  'splenda® sugar blend',
#  'cinnamon sticks plus   garnish',
#  'watermelon rind white part only',
#  'chocolate creamfilled sandwich cookies',
#  'snow crab clusters shelled',
#  'packages flaked coconut',
#  'bitesize corn square cereal   corn chex®',
#  'packages chocolate chip cookie dough',
#  'fruitflavored breakfast cereal   froot loops®',
#  'honey roasted peanuts',
#  'up',
#  'snow peas trimmed  halved crosswise',
#  'mustard oil',
#  'fluid  coconut milk',
#  'dried kombu',
#  'pickled jalapeño pepper',
#  'bottle lemon juice concentrate',
#  'grated parmigianoreggiano cheese',
#  'corn muffin mix   jiffy',
#  'lemonflavored gelatin   jello®',
#  'lowsodium chickpeas   liquid reserved',
#  '% cream halfandhalf',
#  'red onion   quartered  separated',
#  'arugula   dried',
#  'hot capicola coppa',
#  'talian sausage casing',
#  'grape leaves',
#  'sunchokes',
#  'marzipan',
#  'buttery crackers',
#  'strawberry',
#  'shucked oysters',
#  'pastry pie crust',
#  'nutter butter sandwich cookies',
#  'thick bonein center  pork chops',
#  'apples cored  quartered',
#  'chunky natural peanut butter',
#  'onion   thick   separated  rings',
#  'cucumber very',
#  'san marzano tomatoes  other highquality plum tomatoes',
#  'bunches rainbow chard',
#  'serrano pepper  diagonally',
#  'parmesan plus   topping',
#  'cooked kale',
#  'unsweetened tea',
#  'day old bagel',
#  'green bell pepper  in rings',
#  'bunch green onions  green tops reserved',
#  'reduced fat smooth peanut butter',
#  'cooked shortgrain rice',
#  'unsalted sunflower seeds',
#  'fluid  apple schnapps',
#  'nori fumi furikake seaweed  sesame rice seasoning',
#  'packages sweetened gelatin mix   jello®  different colors',
#  'powdered au jus gravy mix',
#  'packages  cranberries',
#  'tomatobasil pasta sauce',
#  'chipotle spice rub',
#  'pineapple chunks in juice',
#  'dried oregano',
#  'cans sweet corn',
#  'lump crabmeat picked free  shell',
#  'cheddar mozzarella  provolone cheese',
#  'powdered black food coloring',
#  'fluid  tequila',
#  'pineapple   cored  cubed',
#  'cans chiliseasoned  tomatoes',
#  'cold cooked spaghetti',
#  'loosely packed baby spinach leaves',
#  'fluid    bottle irish stout beer eg guinness',
#  'powdered chicken bouillon',
#  'romaine lettuce leaves',
#  'chili beans with liquid',
#  'pods whole star anise',
#  'starshaped pastina  acini di pepe',
#  'turkey wings  apart at joints  wing tips discarded',
#  'sweetened condensed milk   eagle brand',
#  'neufchatel cheese  cream cheese',
#  'tomatoes  green chiles   rotel®',
#  'plain full fat yogurt',
#  'mediumlemon lemon',
#  'carnaroli rice',
#  'lowsodium chicken stock  broth',
#  'head cauliflower broken',
#  'ham stock',
#  'chevre soft goat cheese at room temperature',
#  'very   coffee',
#  'orangefleshed sweet potato',
#  'whole lobster tails shelled',
#  'dried rose petals',
#  'green beans washed',
#  'instant strawberry pudding mix',
#  'skinless boneless chicken breasts   chunks',
#  'head  broccoli',
#  'wooden skewers soaked in water',
#  'fluid  passion fruit flavored syrup',
#  'colby jack cheese',
#  'kaiser rolls',
#  'bonein standing rib roast',
#  'grated white cheddar cheese',
#  'drop bitters',
#  'boneless leg  lamb tied in netting',
#  'cold light beer',
#  'melon any type',
#  'bag  tater tots',
#  'firm pears',
#  'sheet reynolds parchment paper',
#  'leftover coffee grounds',
#  'lean  pork',
#  'mixed  melty cheese',
#  'egg substitute liquid',
#  'bag  cranberries   sorted',
#  'cloves garlic bruised',
#  'grated aged asiago cheese',
#  'allpurpose baking mix   bisquick',
#  'hot smoked paprika',
#  'grape  cherry tomatoes',
#  'unsalted beef broth',
#  'red food coloring   desired',
#  'pork liver',
#  'thick rings green bell pepper',
#  'quarts distilled white vinegar',
#  'candied citrus peel',
#  'shaved green onions',
#  'mixed  berries blueberries blackberries raspberries strawberries',
#  'part pinnacle® vodka',
#  'stick unsalted butter melted',
#  'ears  corn husked',
#  'fluid    bottle cream soda',
#  'cooked chicken breast warmed',
#  'zucchini   quartered',
#  'sterilized canning jars with lids  rings',
#  'ozcan',
#  'taco seasoning mix',
#  'milk chocolate candy bars',
#  ...}
